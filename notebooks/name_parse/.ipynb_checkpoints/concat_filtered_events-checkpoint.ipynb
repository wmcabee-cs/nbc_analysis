# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from nbc_analysis import concat_filtered_events
from nbc_analysis.utils.debug_utils import runit

from toolz import first, take,concatv
import re
import pandas as pd
import numpy as np

# %%
df = runit(concat_filtered_events)
# Out:
# created example config file at: /Users/wmcabee/.config/nbc_analysis/extracts.yaml
# >> starting concat for day 20190701
# >> starting show frequency
# >> starting platform frequency
# >> starting ip frequency
# >> end concat_20190701.csv

# %%
df
# Out:
#                                video_cnt  ad_watch_cnt  ad_duration_watched  \
# mpid                 day
# -9223187207509451055 20190701          0             5                103.0
# -9222578500738574457 20190701          2            33                637.0
# -9222548099410079541 20190701          0             1                 30.0
# -9222402859805111336 20190701          6           109               2251.0
# -9221290351807949392 20190701          9            43                878.0
# ...                                  ...           ...                  ...
#  9222118369249001209 20190701          1             1                 15.0
#  9222535954071634881 20190701          1             1                 15.0
#  9222576979530676794 20190701          2            31                647.0
#  9222813729192442880 20190701          1             0                  0.0
#  9223151154174236242 20190701          9             5                 40.0
#
#                                duration_watched  ads_per_video_cnt_avg  \
# mpid                 day
# -9223187207509451055 20190701               0.0                    inf
# -9222578500738574457 20190701              40.0                   16.5
# -9222548099410079541 20190701               0.0                    inf
# -9222402859805111336 20190701             270.0                   18.2
# -9221290351807949392 20190701             179.0                    4.8
# ...                                         ...                    ...
#  9222118369249001209 20190701               0.0                    1.0
#  9222535954071634881 20190701               0.0                    1.0
#  9222576979530676794 20190701              66.0                   15.5
#  9222813729192442880 20190701               0.0                    0.0
#  9223151154174236242 20190701               2.0                    0.6
#
#                                ad_vs_video_time_avg  agg_rec_cnt  \
# mpid                 day
# -9223187207509451055 20190701                   inf            2
# -9222578500738574457 20190701                  15.9            5
# -9222548099410079541 20190701                   inf            1
# -9222402859805111336 20190701                   8.3           10
# -9221290351807949392 20190701                   4.9           12
# ...                                             ...          ...
#  9222118369249001209 20190701                   inf            2
#  9222535954071634881 20190701                   inf            1
#  9222576979530676794 20190701                   9.8            4
#  9222813729192442880 20190701                   NaN            1
#  9223151154174236242 20190701                  20.0            9
#
#                                         most_frequent_show  \
# mpid                 day
# -9223187207509451055 20190701                     Manifest
# -9222578500738574457 20190701            Days of our Lives
# -9222548099410079541 20190701                The InBetween
# -9222402859805111336 20190701                     Dateline
# -9221290351807949392 20190701                   Superstore
# ...                                                    ...
#  9222118369249001209 20190701                     Dateline
#  9222535954071634881 20190701  Late Night with Seth Meyers
#  9222576979530676794 20190701                  This Is Us
#  9222813729192442880 20190701                     Dateline
#  9223151154174236242 20190701                     Dateline
#
#                               most_frequent_platform  \
# mpid                 day
# -9223187207509451055 20190701                 FireTV
# -9222578500738574457 20190701                Android
# -9222548099410079541 20190701                 FireTV
# -9222402859805111336 20190701                 FireTV
# -9221290351807949392 20190701                 FireTV
# ...                                              ...
#  9222118369249001209 20190701                 FireTV
#  9222535954071634881 20190701                Android
#  9222576979530676794 20190701                 FireTV
#  9222813729192442880 20190701             Android TV
#  9223151154174236242 20190701                Android
#
#                                                       most_frequent_ip
# mpid                 day
# -9223187207509451055 20190701                           174.31.193.189
# -9222578500738574457 20190701     2600:1:b26d:4140:8904:92db:8ad2:2de6
# -9222548099410079541 20190701                            47.133.41.248
# -9222402859805111336 20190701   2600:8801:3980:56d:f90b:8651:19fa:c7ff
# -9221290351807949392 20190701                           108.17.159.136
# ...                                                                ...
#  9222118369249001209 20190701                          104.244.241.137
#  9222535954071634881 20190701   2601:200:8000:66c1:b478:4fde:fa8c:53f0
#  9222576979530676794 20190701                              99.1.193.63
#  9222813729192442880 20190701  2607:fb90:a22a:5ea9:1424:233a:8829:9ceb
#  9223151154174236242 20190701  2600:1700:fa00:7ce0:c4c7:e296:845c:7e5f
#
# [55864 rows x 10 columns]

# %%
g, df = next(iter(grouping))

# %%
ds = df.show.value_counts()
# Out:
# Manifest         1
# New Amsterdam    1
# Name: show, dtype: int64

# %%
list(ds.items())
# Out:
# [('Manifest', 1), ('New Amsterdam', 1)]

# %% [markdown]
# ## Exploring dataset

# %%
df = ret
mpids = df.groupby(level=0).size()
mpids.sort_values(ascending=False, inplace=True)

# %%
mpids
# Out:
# mpid
# -3460882801377953287    306
# -8696680083387808440    146
#  1280342646973058262    110
#  7130132102329991613     99
#  3665820832050183348     94
#                        ...
#  1850876285000194073      1
# -5907777658847647130      1
# -2493588285649112202      1
#  5510587066450472508      1
# -363984302145702352       1
# Length: 55864, dtype: int64

# %%
dx = df.loc[[-3460882801377953287, 3665820832050183348]]
dx = dx.set_index('show', append=True)
dx.groupby(dx.index.names).size().unstack().T.fillna('')
# Out:
# mpid                                   -3460882801377953287  \
# show
# Abby's                                                    1
# Blindspot
# Chicago Med                                               7
# Consumer 101                                             10
# Days of our Lives                                         8
# Dracula                                                   6
# Ellen's Game of Games                                     5
# I Feel Bad                                               43
# Journey with Dylan Dreyer                                30
# Late Night with Seth Meyers                              38
# Midnight, Texas                                          15
# Naturally, Danny Seo                                     27
# New Amsterdam                                            15
# Not Set                                                   6
# Shades of Blue                                            6
# The Bionic Woman                                          1
# The Enemy Within                                          7
# The Real Housewives of Beverly Hills
# The Real Housewives of New York City
# The Tonight Show Starring Jimmy Fallon                   16
# The Voyager with Josh Garcia                             38
# This Is Us                                               17
# Vanderpump Rules
# Vets Saving Pets                                          8
# Watch What Happens Live
# Whitney                                                   2
# vanderpump-rules
#
# mpid                                    3665820832050183348
# show
# Abby's
# Blindspot                                                 1
# Chicago Med
# Consumer 101
# Days of our Lives
# Dracula
# Ellen's Game of Games
# I Feel Bad
# Journey with Dylan Dreyer
# Late Night with Seth Meyers
# Midnight, Texas
# Naturally, Danny Seo
# New Amsterdam
# Not Set
# Shades of Blue
# The Bionic Woman
# The Enemy Within
# The Real Housewives of Beverly Hills                      2
# The Real Housewives of New York City                      1
# The Tonight Show Starring Jimmy Fallon
# The Voyager with Josh Garcia
# This Is Us
# Vanderpump Rules                                         65
# Vets Saving Pets
# Watch What Happens Live                                  24
# Whitney
# vanderpump-rules                                          1

# %%
ret.loc[655341257817720116].T
# Out:
# mpid                                                655341257817720116  \
# key                  NBCProd/Android/NBC_20190701215546473870_55769...
# idx                                                               5742
# batch_id                                       b00015_android_20190701
# session_id                                        -1364616974839578558
# customer_id                       dbeb28b2-8867-4a89-bc9e-55aaedaccb12
# ip                                  2607:fb90:5699:9544:0:17:45e6:5801
# platform                                                       Android
# video_type                                                Full Episode
# video_end_type                                              Background
# show                                   Keeping Up With The Kardashians
# season                                                              16
# episode_number                                                    1611
# episode_title                                                Treachery
# event_name                                                   Video End
# start_ts                                                 1562017971614
# end_ts                                                   1562018026699
# end_utc_day                                                   20190701
# end_utc_dt                                         2019-07-01T21:53:46
# video_cnt                                                            1
# ad_watch_cnt                                                         0
# ad_duration_watched                                                  0
# duration_watched                                                     0
#
# mpid                                                655341257817720116  \
# key                  NBCProd/Android/NBC_20190701220108705356_90355...
# idx                                                               3849
# batch_id                                       b00015_android_20190701
# session_id                                         7527271882242572740
# customer_id                       dbeb28b2-8867-4a89-bc9e-55aaedaccb12
# ip                                  2607:fb90:5699:9544:0:17:45e6:5801
# platform                                                       Android
# video_type                                                Full Episode
# video_end_type                                              Background
# show                                   Keeping Up With The Kardashians
# season                                                              16
# episode_number                                                    1611
# episode_title                                                Treachery
# event_name                                                   Video End
# start_ts                                                 1562018295933
# end_ts                                                   1562018303434
# end_utc_day                                                   20190701
# end_utc_dt                                         2019-07-01T21:58:23
# video_cnt                                                            1
# ad_watch_cnt                                                         1
# ad_duration_watched                                                  3
# duration_watched                                                     0
#
# mpid                                                655341257817720116
# key                  NBCProd/Android/NBC_20190701215551567385_74888...
# idx                                                               5426
# batch_id                                       b00015_android_20190701
# session_id                                         7699999041763572801
# customer_id                                                       None
# ip                                  2607:fb90:5699:9544:0:17:45e6:5801
# platform                                                       Android
# video_type                                                Full Episode
# video_end_type                                              Background
# show                                   Keeping Up With The Kardashians
# season                                                              16
# episode_number                                                    1611
# episode_title                                                Treachery
# event_name                                                   Video End
# start_ts                                                 1562018057722
# end_ts                                                   1562018064846
# end_utc_day                                                   20190701
# end_utc_dt                                         2019-07-01T21:54:24
# video_cnt                                                            1
# ad_watch_cnt                                                         1
# ad_duration_watched                                                  3
# duration_watched                                                     0
