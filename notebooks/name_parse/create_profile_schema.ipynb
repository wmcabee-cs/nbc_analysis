# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from nbc_analysis.utils.debug_utils import runit
from nbc_analysis.utils.config_utils import get_config
from nbc_analysis import create_profile
from pathlib import Path
from toolz import concatv

# %%
runit(create_profile)
# Out:
# created example config file at: /Users/wmcabee/.config/nbc_analysis/extracts.yaml
#                       mpid       day  video_cnt  ad_watch_cnt  \
# 0     -9223187207509451055  20190701          0             5
# 1     -9222578500738574457  20190701          2            33
# 2     -9222548099410079541  20190701          0             1
# 3     -9222402859805111336  20190701          6           109
# 4     -9221290351807949392  20190701          9            43
# ...                    ...       ...        ...           ...
# 55859  9222118369249001209  20190701          1             1
# 55860  9222535954071634881  20190701          1             1
# 55861  9222576979530676794  20190701          2            31
# 55862  9222813729192442880  20190701          1             0
# 55863  9223151154174236242  20190701          9             5
#
#        ad_duration_watched  duration_watched  ads_per_video_cnt_avg  \
# 0                    103.0               0.0                    inf
# 1                    637.0              40.0                   16.5
# 2                     30.0               0.0                    inf
# 3                   2251.0             270.0                   18.2
# 4                    878.0             179.0                    4.8
# ...                    ...               ...                    ...
# 55859                 15.0               0.0                    1.0
# 55860                 15.0               0.0                    1.0
# 55861                647.0              66.0                   15.5
# 55862                  0.0               0.0                    0.0
# 55863                 40.0               2.0                    0.6
#
#        ad_vs_video_time_avg  agg_rec_cnt           most_frequent_show  \
# 0                       inf            2                     Manifest
# 1                      15.9            5            Days of our Lives
# 2                       inf            1                The InBetween
# 3                       8.3           10                     Dateline
# 4                       4.9           12                   Superstore
# ...                     ...          ...                          ...
# 55859                   inf            2                     Dateline
# 55860                   inf            1  Late Night with Seth Meyers
# 55861                   9.8            4                  This Is Us
# 55862                   NaN            1                     Dateline
# 55863                  20.0            9                     Dateline
#
#       most_frequent_platform                         most_frequent_ip
# 0                     FireTV                           174.31.193.189
# 1                    Android     2600:1:b26d:4140:8904:92db:8ad2:2de6
# 2                     FireTV                            47.133.41.248
# 3                     FireTV   2600:8801:3980:56d:f90b:8651:19fa:c7ff
# 4                     FireTV                           108.17.159.136
# ...                      ...                                      ...
# 55859                 FireTV                          104.244.241.137
# 55860                Android   2601:200:8000:66c1:b478:4fde:fa8c:53f0
# 55861                 FireTV                              99.1.193.63
# 55862             Android TV  2607:fb90:a22a:5ea9:1424:233a:8829:9ceb
# 55863                Android  2600:1700:fa00:7ce0:c4c7:e296:845c:7e5f
#
# [55864 rows x 12 columns]

# %%
files = concatv(concat_d.glob('*.csv'), concat_d.glob('*.csv.gz'))
list(files)
# Out:
# [PosixPath('/Users/wmcabee/DATA/NBC2/concat/concat_20190701.csv')]
