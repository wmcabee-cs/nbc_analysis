# %%
# %reload_ext autoreload
# %autoreload 2

from pathlib import Path
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
from nbc_analysis.utils.config_utils import get_config
from nbc_analysis.analysis import write_viewer_counts

config = get_config()
# Out:
# >> created example config file '/Users/wmcabee/.config/nbc_analysis/config_example.yaml'
# >> loaded config '/Users/wmcabee/.config/nbc_analysis/config.yaml'

# %%
indir = Path('/Users/wmcabee/Dropbox (Cognitive Scale)/NBC Analysis/data/NBC2/batches')
df = write_viewer_counts(config_f='default', indir=indir)
# Out:
# >> created example config file '/Users/wmcabee/.config/nbc_analysis/config_example.yaml'
# >> Using default config
# >> read ve_20190704_0007, 50456
# >> read ve_20190701_0015, 49410
# >> read ve_20190702_0008, 49931
# >> read ve_20190705_0011, 49018
# >> read ve_20190707_0006, 50379
# >> read ve_20190703_0002, 49759
# >> read ve_20190701_0009, 48840
# >> read ve_20190702_0014, 48910
# >> read ve_20190706_0010, 49301
# >> read ve_20190706_0001, 49964
# >> read ve_20190702_0005, 49638
# >> read ve_20190703_0013, 48810
# >> read ve_20190705_0000, 50300
# >> read ve_20190701_0004, 50281
# >> read ve_20190702_0019, 6171
# >> read ve_20190704_0016, 50504
# >> read ve_20190703_0016, 49297
# >> read ve_20190707_0012, 49758
# >> read ve_20190706_0004, 49592
# >> read ve_20190702_0000, 49700
# >> read ve_20190704_0013, 49730
# >> read ve_20190705_0005, 49941
# >> read ve_20190701_0001, 50255
# >> read ve_20190701_0010, 48508
# >> read ve_20190705_0014, 49580
# >> read ve_20190706_0009, 49187
# >> read ve_20190704_0002, 50384
# >> read ve_20190702_0011, 48906
# >> read ve_20190705_0008, 48585
# >> read ve_20190706_0015, 50190
# >> read ve_20190707_0003, 50451
# >> read ve_20190703_0007, 50085
# >> read ve_20190707_0004, 50524
# >> read ve_20190703_0000, 50087
# >> read ve_20190702_0016, 49601
# >> read ve_20190706_0012, 49454
# >> read ve_20190704_0005, 49944
# >> read ve_20190701_0017, 33398
# >> read ve_20190705_0013, 49213
# >> read ve_20190705_0002, 49895
# >> read ve_20190701_0006, 50035
# >> read ve_20190704_0014, 50223
# >> read ve_20190707_0009, 49648
# >> read ve_20190706_0003, 49699
# >> read ve_20190702_0007, 50260
# >> read ve_20190703_0011, 48862
# >> read ve_20190704_0008, 50183
# >> read ve_20190707_0015, 50353
# >> read ve_20190703_0008, 50091
# >> read ve_20190704_0011, 49491
# >> read ve_20190705_0007, 49000
# >> read ve_20190701_0003, 49923
# >> read ve_20190703_0014, 49211
# >> read ve_20190707_0010, 49803
# >> read ve_20190706_0006, 49704
# >> read ve_20190702_0002, 49635
# >> read ve_20190702_0013, 48926
# >> read ve_20190706_0017, 34372
# >> read ve_20190707_0001, 50712
# >> read ve_20190703_0005, 50213
# >> read ve_20190701_0012, 49182
# >> read ve_20190705_0016, 48987
# >> read ve_20190704_0000, 49711
# >> read ve_20190703_0019, 49414
# >> read ve_20190706_0005, 49909
# >> read ve_20190702_0001, 49837
# >> read ve_20190703_0017, 49539
# >> read ve_20190703_0020, 34914
# >> read ve_20190707_0013, 50051
# >> read ve_20190705_0004, 49223
# >> read ve_20190701_0000, 49820
# >> read ve_20190704_0012, 49870
# >> read ve_20190704_0003, 49986
# >> read ve_20190701_0011, 49030
# >> read ve_20190706_0008, 49698
# >> read ve_20190705_0015, 49904
# >> read ve_20190707_0002, 50306
# >> read ve_20190703_0006, 49508
# >> read ve_20190702_0010, 48659
# >> read ve_20190706_0014, 49667
# >> read ve_20190705_0009, 48917
# >> read ve_20190702_0009, 48551
# >> read ve_20190701_0014, 49703
# >> read ve_20190705_0010, 49001
# >> read ve_20190704_0006, 50167
# >> read ve_20190702_0015, 49820
# >> read ve_20190701_0008, 49300
# >> read ve_20190706_0011, 49381
# >> read ve_20190707_0007, 50524
# >> read ve_20190703_0003, 50094
# >> read ve_20190703_0012, 49160
# >> read ve_20190707_0016, 10181
# >> read ve_20190706_0000, 49661
# >> read ve_20190702_0004, 49484
# >> read ve_20190704_0017, 31773
# >> read ve_20190705_0001, 49953
# >> read ve_20190702_0018, 49741
# >> read ve_20190701_0005, 50231
# >> read ve_20190705_0006, 49965
# >> read ve_20190701_0002, 50637
# >> read ve_20190703_0009, 50126
# >> read ve_20190704_0010, 49320
# >> read ve_20190706_0007, 49997
# >> read ve_20190702_0003, 50121
# >> read ve_20190703_0015, 49271
# >> read ve_20190707_0011, 49780
# >> read ve_20190707_0000, 50089
# >> read ve_20190703_0004, 50113
# >> read ve_20190702_0012, 48944
# >> read ve_20190706_0016, 50415
# >> read ve_20190704_0001, 50043
# >> read ve_20190703_0018, 49386
# >> read ve_20190701_0013, 49308
# >> read ve_20190702_0017, 49309
# >> read ve_20190706_0013, 50090
# >> read ve_20190707_0005, 50356
# >> read ve_20190703_0001, 49754
# >> read ve_20190701_0016, 49743
# >> read ve_20190705_0012, 49232
# >> read ve_20190704_0004, 49707
# >> read ve_20190707_0008, 49742
# >> read ve_20190704_0015, 50432
# >> read ve_20190705_0003, 50019
# >> read ve_20190701_0007, 50131
# >> read ve_20190703_0010, 48635
# >> read ve_20190707_0014, 50204
# >> read ve_20190704_0009, 49534
# >> read ve_20190706_0002, 49668
# >> read ve_20190702_0006, 50183
# wrote viewer counts,file=/Users/wmcabee/DATA/NBC2/ana/viewer_counts.parquet],cnt=3068956

# %%
dx = df.set_index(['mpid','day']).event_cnt
dx.sort_index(inplace=True)
dx = dx.groupby(level=['mpid','day']).sum()
dx = dx.unstack()
COUNTS = dx

# %%
dx = COUNTS.copy()
dx = dx.notna().astype(np.int)
OCCURANCES = dx

# %%
def get_cum_unique(idx):
    df = OCCURANCES.iloc[:, :idx]
    total = df.max(axis=1).sum()
    return total

reader = ( idx for idx, dc in enumerate(OCCURANCES.columns,start=1))
cum_unique = map(get_cum_unique, reader)

df = pd.DataFrame({'cum_unique': cum_unique}, index=OCCURANCES.columns)
df['new_viewers'] = df.cum_unique.diff()
df = df.div(1000).round(1)
ax =df.plot(marker='x')
ax.set_title("Unique users for sampled week")
ax.set_xlabel('day')
ax.set_ylabel('unique users (K)')
df
# Out:
#           cum_unique  new_viewers
# day
# 20190701       222.5          NaN
# 20190702       409.6        187.0
# 20190703       583.7        174.2
# 20190704       720.0        136.2
# 20190705       836.7        116.7
# 20190706       950.6        114.0
# 20190707      1059.9        109.3

# %%
df.diff()
# Out:
#           cum_unique
# day
# 20190701         NaN
# 20190702    187032.0
# 20190703    174177.0
# 20190704    136218.0
# 20190705    116705.0
# 20190706    113951.0
# 20190707    109313.0
