# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import s3fs

# %%
fs = s3fs.S3FileSystem()

# %%
fs.ls('nbc-digital-cloned/NBCProd/Android')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-0b1a662e4234> in <module>
# ----> 1 fs.ls('nbc-digital-cloned/NBCProd/Android')
#
# ~/_NBC/nbc_analysis/venv/lib/python3.7/site-packages/s3fs/core.py in ls(self, path, detail, refresh, **kwargs)
#     528         """
#     529         path = self._strip_protocol(path).rstrip('/')
# --> 530         files = self._ls(path, refresh=refresh)
#     531         if not files:
#     532             files = self._ls(self._parent(path), refresh=refresh)
#
# ~/_NBC/nbc_analysis/venv/lib/python3.7/site-packages/s3fs/core.py in _ls(self, path, refresh)
#     450             return self._lsbuckets(refresh)
#     451         else:
# --> 452             return self._lsdir(path, refresh)
#     453
#     454     def exists(self, path):
#
# ...
