# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from nbc_analysis.utils import config_utils
from nbc_analysis.utils.debug_utils import runit
from pathlib import Path
from toolz import take, partial
import pandas as pd
import numpy as np
from pandas_summary import DataFrameSummary
from collections import defaultdict
import itertools
from pandas.util import hash_pandas_object

from nbc_analysis.utils.dim_utils import build_nk_dim, build_hash_dim, build_unique_set

# %%
CONFIG = config_utils.get_config(config='default')
SOURCE_D = Path(CONFIG['WORK_D']) / 'query'
WORK_D = Path(CONFIG['WORK_D']) / 'ip_model'
CONFIG
# Out:
# 2019-10-21 13:41:42,367|WARNING|nbc_analysis.utils.config_utils|The 'default' config is intended for testing only. For production, use /Users/wmcabee/.config/nbc_analysis/config.yaml
# {'CALENDAR_START_DAY_KEY': '20170101',
#  'CALENDAR_END_DAY_KEY': '20210101',
#  'CALENDAR_D': '/Users/wmcabee/DATA/NBC/calendar',
#  'ANALYSIS_D': '/Users/wmcabee/DATA/NBC/ana',
#  'RUNS_D': '/Users/wmcabee/DATA/NBC/runs',
#  'WORK_D': '/Users/wmcabee/DATA/NBC/work',
#  'VIDEO_END_BUCKET': 'nbc-event',
#  'VIDEO_END_PARTITIONS_BUCKET': 'nbc-partitions-video-end-protect',
#  'GEN_PROFILE_SOURCE': 'nbc-partitions-video-end',
#  'BATCH_SIZE': 200000000,
#  'GEOLITE2_DB': '/Users/wmcabee/DATA/NBC/datasets/GeoLite2-City_20191001/GeoLite2-City.mmdb',
#  'VIEWER_SOURCE_BUCKET': 'nbc-events-partitioned',
#  'VIEWER_PARTITION_COUNT': 60,
#  'VIEWER_PARTITION_D': '/Users/wmcabee/DATA/NBC/viewer_partitions',
#  'LIMIT_FILES_PER_DAY': 20,
#  'BATCH_LIMIT': 2,
#  'BATCH_FILES_LIMIT': 2,
#  'MERGE_LIMIT': 2,
#  'PROFILE_PER_WEEK_LIMIT': 1000}

# %%
reader = SOURCE_D.glob('*')
reader = take(3, reader)
df = pd.concat(map(pd.read_parquet, reader))
DATA = df.sort_values('event_start_unixtime_ms', ascending=False).reset_index(drop=True)
DATA.head(3).T
# Out:
#                                                                 0  \
# batch_id                                         ve_20190930_0003
# file                       NBC_App_20190930033852328226_68559.txt
# file_idx                                                     1532
# asof_dt                               2019-10-11T19:16:54.139463Z
# mpid                                          7752839992563167640
# nbc_profile                                       Unauthenticated
# mvpd                                              Unauthenticated
# event_name                                              Video End
# event_type                                           custom_event
# platform                                                  Not Set
# data_connection_type                                      Not Set
# ip                          2603:9001:3d0b:6300:849:27f1:5264:f16
# video_id                                                  4036451
# video_type                                              Highlight
# show                                                 Chicago P.D.
# season                                                          7
# episode_number                                                  1
# episode_title                             You Went Behind My Back
# genre                                                       Drama
# video_duration                                                  1
# video_end_type                                              Close
# resume                                                      False
# event_id                                     -2165054904579433498
# session_id                                    9025237351300304311
# video_duration_watched                          0.766666666666667
# event_start_unixtime_ms                             1569987267779
# session_start_unixtime_ms                           1569986197038
# resume_time                                                  None
# viewer_partition                                                0
#
#                                                                  1  \
# batch_id                                          ve_20191001_0004
# file                            NBC_20191001045954961424_64260.txt
# file_idx                                                      2017
# asof_dt                                2019-10-11T19:36:20.621381Z
# mpid                                           1074643952692953660
# nbc_profile                                        Unauthenticated
# mvpd                                                           DTV
# event_name                                               Video End
# event_type                                            custom_event
# platform                                                      tvOS
# data_connection_type                                          wifi
# ip                         2600:6c67:207f:f473:48a5:57d4:5c68:ce06
# video_id                                                   3675825
# video_type                                            Full Episode
# show                                                      A.P. Bio
# season                                                           1
# episode_number                                                   5
# episode_title                                     Dating Toledoans
# genre                                                       Comedy
# video_duration                                                  22
# video_end_type                                               Close
# resume                                                       False
# event_id                                      -7801022097402524755
# session_id                                     1222968412423828282
# video_duration_watched                                          22
# event_start_unixtime_ms                              1569905923977
# session_start_unixtime_ms                            1569898352051
# resume_time                                                   None
# viewer_partition                                                 0
#
#                                                                            2
# batch_id                                                    ve_20191001_0004
# file                                  NBC_App_20191001045930779268_51913.txt
# file_idx                                                                2015
# asof_dt                                          2019-10-11T19:36:20.621381Z
# mpid                                                    -7141178299446626700
# nbc_profile                                                  Unauthenticated
# mvpd                                                         Unauthenticated
# event_name                                                         Video End
# event_type                                                      custom_event
# platform                                                             Not Set
# data_connection_type                                                 Not Set
# ip                                                             66.165.21.179
# video_id                                                             4037285
# video_type                                                   Current Preview
# show                                                     Saturday Night Live
# season                                                                    45
# episode_number                                                             1
# episode_title              Saturday Is a Big Night for Woody Harrelson an...
# genre                                                                 Comedy
# video_duration                                                             1
# video_end_type                                                         Close
# resume                                                                 False
# event_id                                                -7502478291025245391
# session_id                                               6659201435104007237
# video_duration_watched                                                     0
# event_start_unixtime_ms                                        1569905885966
# session_start_unixtime_ms                                      1569903139264
# resume_time                                                             None
# viewer_partition                                                           0

# %%
from nbc_analysis.dims.main import main as build_dims
from nbc_analysis.utils.toml_utils import get_config
#     bld_ip_set = partial(dim_utils.build_unique_set, cols=['ip']),

# %%
config = get_config('test')
cfg = config['normalize']
cfg
# Out:
# {'normalize_d': '/Users/wmcabee/DATA/NBC/normalize'}

# %%
df = runit(build_dims,cfg=cfg,data=DATA.copy())
# Out:
# 2019-10-21 13:39:57,219|INFO|nbc_analysis.dims.main|start normalize video end, {'normalize_d': '/Users/wmcabee/DATA/NBC/normalize'}
# 2019-10-21 13:39:57,221|INFO|nbc_analysis.dims.main|start clean input
# 2019-10-21 13:39:58,592|INFO|nbc_analysis.dims.main|end clean input
# 2019-10-21 13:39:58,604|INFO|nbc_analysis.dims.main|deriving timestamp information
# 2019-10-21 13:40:03,096|INFO|nbc_analysis.dims.main|building date_utc_key set
# 2019-10-21 13:40:03,197|INFO|nbc_analysis.utils.file_utils|start write file,/Users/wmcabee/DATA/NBC/normalize/day_utc_keys.parquet,record_cnt=236
# 2019-10-21 13:40:03,203|INFO|nbc_analysis.utils.file_utils|end write file,/Users/wmcabee/DATA/NBC/normalize/day_utc_keys.parquet,record_cnt=236
# 2019-10-21 13:40:03,329|INFO|nbc_analysis.utils.file_utils|start write file,/Users/wmcabee/DATA/NBC/normalize/video_dim.parquet,record_cnt=11472
# 2019-10-21 13:40:03,356|INFO|nbc_analysis.utils.file_utils|end write file,/Users/wmcabee/DATA/NBC/normalize/video_dim.parquet,record_cnt=11472
# 2019-10-21 13:40:03,475|INFO|nbc_analysis.utils.file_utils|start write file,/Users/wmcabee/DATA/NBC/normalize/event_type_dim.parquet,record_cnt=1
# 2019-10-21 13:40:03,478|INFO|nbc_analysis.utils.file_utils|end write file,/Users/wmcabee/DATA/NBC/normalize/event_type_dim.parquet,record_cnt=1
# 2019-10-21 13:40:03,601|INFO|nbc_analysis.utils.file_utils|start write file,/Users/wmcabee/DATA/NBC/normalize/platform_dim.parquet,record_cnt=11
# 2019-10-21 13:40:03,603|INFO|nbc_analysis.utils.file_utils|end write file,/Users/wmcabee/DATA/NBC/normalize/platform_dim.parquet,record_cnt=11
# 2019-10-21 13:40:03,721|INFO|nbc_analysis.utils.file_utils|start write file,/Users/wmcabee/DATA/NBC/normalize/profile_dim.parquet,record_cnt=325
# 2019-10-21 13:40:03,725|INFO|nbc_analysis.utils.file_utils|end write file,/Users/wmcabee/DATA/NBC/normalize/profile_dim.parquet,record_cnt=325
# 2019-10-21 13:40:03,840|INFO|nbc_analysis.utils.file_utils|start write file,/Users/wmcabee/DATA/NBC/normalize/end_type_dim.parquet,record_cnt=12
# 2019-10-21 13:40:03,843|INFO|nbc_analysis.utils.file_utils|end write file,/Users/wmcabee/DATA/NBC/normalize/end_type_dim.parquet,record_cnt=12
# 2019-10-21 13:40:03,891|INFO|nbc_analysis.utils.file_utils|start write file,/Users/wmcabee/DATA/NBC/normalize/f_video_end.parquet,record_cnt=239388
# 2019-10-21 13:40:04,151|INFO|nbc_analysis.utils.file_utils|end write file,/Users/wmcabee/DATA/NBC/normalize/f_video_end.parquet,record_cnt=239388
# 2019-10-21 13:40:04,152|INFO|nbc_analysis.dims.main|end normalize video end

# %%
df.sample(20).T
# Out:
#                                                          233431  \
# day_utc_key                                            20190805
# video_key                                   5974376419208466435
# platform_key                                2356253770914521728
# profile_key                                 5612241246451325071
# end_type_key                                7968799331887820946
# event_key                                  10286261140990397066
# ip                      2604:6000:b7c8:9000:8814:6938:757b:f72e
# mpid                                       -8748596183250385140
# event_start_dt                          20190805T042445.323999Z
# video_duration_watched                                        0
# resume_time                                                 NaN
# _file                        NBC_20190805042524602800_23997.txt
# _file_idx                                                  1850
# _batch_id                                      ve_20190805_0002
# _viewer_partition                                             0
# _last_upd_dt                                      1564979085324
#
#                                                         235413  \
# day_utc_key                                           20190805
# video_key                                  7086799438914668644
# platform_key                              13512958757101649953
# profile_key                                5612241246451325071
# end_type_key                               1543738608339601720
# event_key                                 10286261140990397066
# ip                                                108.32.74.46
# mpid                                      -6342832917772954080
# event_start_dt                         20190805T020854.970999Z
# video_duration_watched                                       4
# resume_time                                                NaN
# _file                   NBC_App_20190805021025948219_14519.txt
# _file_idx                                                  907
# _batch_id                                     ve_20190805_0001
# _viewer_partition                                            0
# _last_upd_dt                                     1564970934971
#
#                                                     182413  \
# day_utc_key                                       20190808
# video_key                             10302958059812242463
# platform_key                           2356253770914521728
# profile_key                            4488713565721507824
# end_type_key                          15654977777582709682
# event_key                             10286261140990397066
# ip                                           70.124.51.167
# mpid                                  -6319859633989571700
# event_start_dt                     20190808T171230.713000Z
# video_duration_watched                                  36
# resume_time                                            NaN
# _file                   NBC_20190808171929199471_54486.txt
# _file_idx                                             6135
# _batch_id                                 ve_20190808_0005
# _viewer_partition                                        0
# _last_upd_dt                                 1565284350713
#
#                                                     232852  \
# day_utc_key                                       20190805
# video_key                             13815263033873437718
# platform_key                          14339460432746565579
# profile_key                            5894746954545069528
# end_type_key                           1543738608339601720
# event_key                             10286261140990397066
# ip                                           70.176.157.54
# mpid                                   3273324526978898520
# event_start_dt                     20190805T052035.660000Z
# video_duration_watched                                  37
# resume_time                                            NaN
# _file                   NBC_20190805052625931334_50271.txt
# _file_idx                                             2277
# _batch_id                                 ve_20190805_0002
# _viewer_partition                                        0
# _last_upd_dt                                 1564982435660
#
#                                                     80278   \
# day_utc_key                                       20190815
# video_key                              7776021874770871163
# platform_key                           2356253770914521728
# profile_key                            5612241246451325071
# end_type_key                           7968799331887820946
# event_key                             10286261140990397066
# ip                                           64.85.131.143
# mpid                                   2011478895614865900
# event_start_dt                     20190815T152552.891999Z
# video_duration_watched                                   1
# resume_time                                            NaN
# _file                   NBC_20190815153849377350_99818.txt
# _file_idx                                             7146
# _batch_id                                 ve_20190815_0006
# _viewer_partition                                        0
# _last_upd_dt                                 1565882752892
#
#                                                     68008   \
# day_utc_key                                       20190816
# video_key                             18154915801531298659
# platform_key                          13757614714000885976
# profile_key                           16536766980393665541
# end_type_key                          10155504590337046581
# event_key                             10286261140990397066
# ip                                          184.155.72.107
# mpid                                  -7242001024800614040
# event_start_dt                     20190816T050357.265000Z
# video_duration_watched                                  23
# resume_time                                           1355
# _file                   NBC_20190816050646147077_68384.txt
# _file_idx                                             2141
# _batch_id                                 ve_20190816_0003
# _viewer_partition                                        0
# _last_upd_dt                                 1565931837265
#
#                                                          47135   \
# day_utc_key                                            20190817
# video_key                                   4261373564220461998
# platform_key                                2356253770914521728
# profile_key                                 4488713565721507824
# end_type_key                               10155504590337046581
# event_key                                  10286261140990397066
# ip                      2606:a000:1313:c30f:a8f6:e07a:fe87:53f2
# mpid                                        4452628246932079680
# event_start_dt                          20190817T180510.867000Z
# video_duration_watched                                       40
# resume_time                                               26.19
# _file                        NBC_20190817180750822870_40371.txt
# _file_idx                                                  7065
# _batch_id                                      ve_20190817_0006
# _viewer_partition                                             0
# _last_upd_dt                                      1566065110867
#
#                                                         66409   \
# day_utc_key                                           20190816
# video_key                                  5471205157353872452
# platform_key                              13512958757101649953
# profile_key                                5612241246451325071
# end_type_key                              14134703689083528527
# event_key                                 10286261140990397066
# ip                                              47.218.102.179
# mpid                                        919966794826448700
# event_start_dt                         20190816T085626.075999Z
# video_duration_watched                                 38.9167
# resume_time                                               2189
# _file                   NBC_App_20190816090024904431_17493.txt
# _file_idx                                                 3778
# _batch_id                                     ve_20190816_0004
# _viewer_partition                                            0
# _last_upd_dt                                     1565945786076
#
#                                                          180534  \
# day_utc_key                                            20190808
# video_key                                   6966318016900676689
# platform_key                               14329322867388532199
# profile_key                                13998642882195919910
# end_type_key                                7968799331887820946
# event_key                                  10286261140990397066
# ip                      2600:1003:b45f:ab5d:5c2c:847d:d28a:c344
# mpid                                         271946120873688540
# event_start_dt                          20190808T193101.582000Z
# video_duration_watched                                       10
# resume_time                                                 NaN
# _file                        NBC_20190808193332722910_68787.txt
# _file_idx                                                  7327
# _batch_id                                      ve_20190808_0006
# _viewer_partition                                             0
# _last_upd_dt                                      1565292661582
#
#                                                          165187  \
# day_utc_key                                            20190809
# video_key                                   1537790367703820287
# platform_key                                2356253770914521728
# profile_key                                15590532172262057591
# end_type_key                               10155504590337046581
# event_key                                  10286261140990397066
# ip                      2605:e000:6001:da00:41b9:ede7:783a:deb3
# mpid                                        7406593231630017300
# event_start_dt                          20190809T190443.714999Z
# video_duration_watched                                       18
# resume_time                                              839.68
# _file                        NBC_20190809190659829534_97354.txt
# _file_idx                                                  7967
# _batch_id                                      ve_20190809_0007
# _viewer_partition                                             0
# _last_upd_dt                                      1565377483715
#
#                                                     76497   \
# day_utc_key                                       20190815
# video_key                              7293329942964121006
# platform_key                          14339460432746565579
# profile_key                           13998642882195919910
# end_type_key                           1543738608339601720
# event_key                             10286261140990397066
# ip                                           67.246.229.90
# mpid                                   1879773206954595120
# event_start_dt                     20190815T203040.721999Z
# video_duration_watched                                  21
# resume_time                                            NaN
# _file                   NBC_20190815203147034764_91042.txt
# _file_idx                                             9668
# _batch_id                                 ve_20190815_0008
# _viewer_partition                                        0
# _last_upd_dt                                 1565901040722
#
#                                                         88464   \
# day_utc_key                                           20190815
# video_key                                  7255127346109894978
# platform_key                              13512958757101649953
# profile_key                                5612241246451325071
# end_type_key                               1543738608339601720
# event_key                                 10286261140990397066
# ip                      2601:18a:c680:18aa:fc22:bac9:97db:27fe
# mpid                                       4734193781632410360
# event_start_dt                         20190815T014201.042999Z
# video_duration_watched                               0.0333333
# resume_time                                                NaN
# _file                   NBC_App_20190815014647876094_94206.txt
# _file_idx                                                  745
# _batch_id                                     ve_20190815_0000
# _viewer_partition                                            0
# _last_upd_dt                                     1565833321043
#
#                                                         233923  \
# day_utc_key                                           20190805
# video_key                                  6248434395585512718
# platform_key                              13512958757101649953
# profile_key                               16649600711423100378
# end_type_key                              14134703689083528527
# event_key                                 10286261140990397066
# ip                                                73.217.94.61
# mpid                                       4821683653720536360
# event_start_dt                         20190805T034646.970999Z
# video_duration_watched                                   30.55
# resume_time                                               1820
# _file                   NBC_App_20190805034946847635_35714.txt
# _file_idx                                                 1600
# _batch_id                                     ve_20190805_0002
# _viewer_partition                                            0
# _last_upd_dt                                     1564976806971
#
#                                                         204571  \
# day_utc_key                                           20190807
# video_key                                  7626628701902925611
# platform_key                              13512958757101649953
# profile_key                                5612241246451325071
# end_type_key                               1543738608339601720
# event_key                                 10286261140990397066
# ip                                               73.96.102.101
# mpid                                      -8106567421168388760
# event_start_dt                         20190807T032509.039999Z
# video_duration_watched                                       0
# resume_time                                                NaN
# _file                   NBC_App_20190807032737825173_12571.txt
# _file_idx                                                 1437
# _batch_id                                     ve_20190807_0002
# _viewer_partition                                            0
# _last_upd_dt                                     1565148309040
#
#                                                       66784   \
# day_utc_key                                         20190816
# video_key                               16068638094392870465
# platform_key                            14329322867388532199
# profile_key                              5612241246451325071
# end_type_key                             1543738608339601720
# event_key                               10286261140990397066
# ip                      2600:1:f440:e6dc:b152:6838:20b6:be76
# mpid                                    -6731517051670973580
# event_start_dt                       20190816T073058.528000Z
# video_duration_watched                                    11
# resume_time                                              NaN
# _file                     NBC_20190816074309362555_60103.txt
# _file_idx                                               3239
# _batch_id                                   ve_20190816_0004
# _viewer_partition                                          0
# _last_upd_dt                                   1565940658528
#
#                                                     132494  \
# day_utc_key                                       20190812
# video_key                             15990715261947436706
# platform_key                           2356253770914521728
# profile_key                            7117404081290979179
# end_type_key                           7968799331887820946
# event_key                             10286261140990397066
# ip                                            4.79.236.140
# mpid                                  -3713282823497102760
# event_start_dt                     20190812T032033.262000Z
# video_duration_watched                                   0
# resume_time                                            NaN
# _file                   NBC_20190812032258067231_16157.txt
# _file_idx                                             1410
# _batch_id                                 ve_20190812_0001
# _viewer_partition                                        0
# _last_upd_dt                                 1565580033262
#
#                                                          53020   \
# day_utc_key                                            20190817
# video_key                                   5335255399160415779
# platform_key                               16889002418789577125
# profile_key                                 5779157300040046490
# end_type_key                                1543738608339601720
# event_key                                  10286261140990397066
# ip                      2600:1700:53d3:c010:a1a1:ebb5:c0bc:8f4d
# mpid                                       -2141746609865946660
# event_start_dt                          20190817T045051.552999Z
# video_duration_watched                                        9
# resume_time                                                 NaN
# _file                        NBC_20190817045529257561_15510.txt
# _file_idx                                                  2060
# _batch_id                                      ve_20190817_0003
# _viewer_partition                                             0
# _last_upd_dt                                      1566017451553
#
#                                                         152103  \
# day_utc_key                                           20190810
# video_key                                  9926254626702259531
# platform_key                              14329322867388532199
# profile_key                                5612241246451325071
# end_type_key                               1543738608339601720
# event_key                                 10286261140990397066
# ip                      2600:1007:b11c:6c40:64c5:e850:add:4fb5
# mpid                                        -59600491854572880
# event_start_dt                         20190810T172243.801000Z
# video_duration_watched                                      10
# resume_time                                                NaN
# _file                       NBC_20190812081331237897_09015.txt
# _file_idx                                                 3434
# _batch_id                                     ve_20190812_0003
# _viewer_partition                                            0
# _last_upd_dt                                     1565457763801
#
#                                                     46904   \
# day_utc_key                                       20190817
# video_key                              3802226890873589879
# platform_key                           2356253770914521728
# profile_key                            5612241246451325071
# end_type_key                          10155504590337046581
# event_key                             10286261140990397066
# ip                                             50.106.1.84
# mpid                                   3637447334739922140
# event_start_dt                     20190817T183004.971999Z
# video_duration_watched                                  37
# resume_time                                         933.84
# _file                   NBC_20190817183238240496_55352.txt
# _file_idx                                             7212
# _batch_id                                 ve_20190817_0006
# _viewer_partition                                        0
# _last_upd_dt                                 1566066604972
#
#                                                          94570
# day_utc_key                                            20190814
# video_key                                   1623909439111523738
# platform_key                               14329322867388532199
# profile_key                                13998642882195919910
# end_type_key                                7968799331887820946
# event_key                                  10286261140990397066
# ip                      2600:100d:b169:1a1a:d076:5cd5:2b29:e7e6
# mpid                                       -3526221936698499660
# event_start_dt                          20190814T181910.286000Z
# video_duration_watched                                       13
# resume_time                                                 NaN
# _file                        NBC_20190814182417747022_84904.txt
# _file_idx                                                  7694
# _batch_id                                      ve_20190814_0007
# _viewer_partition                                             0
# _last_upd_dt                                      1565806750286
