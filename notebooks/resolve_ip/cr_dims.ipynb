# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from nbc_analysis.utils.debug_utils import runit
from pathlib import Path
from toolz import take, partial
import pandas as pd
import numpy as np
from pandas_summary import DataFrameSummary
from nbc_analysis.dims.main import main as build_dims
from nbc_analysis.utils.toml_utils import get_config
from nbc_analysis.utils.file_utils import read_parquet

# %%
config = get_config('test')
cfg = config['normalize']
cfg
# Out:
# {'test_input_d': '/Users/wmcabee/DATA/NBC/work/query',
#  'normalize_d': '/Users/wmcabee/DATA/NBC/normalize'}

# %%
# %%time
df = runit(build_dims,cfg=cfg)
# Out:
# 2019-10-21 16:03:17,036|INFO|nbc_analysis.dims.main|start normalize video end, {'test_input_d': '/Users/wmcabee/DATA/NBC/work/query', 'normalize_d': '/Users/wmcabee/DATA/NBC/normalize'}
# 2019-10-21 16:03:17,038|INFO|nbc_analysis.utils.file_utils|start read parquet dir,file_cnt=12
# 2019-10-21 16:03:19,822|INFO|nbc_analysis.utils.file_utils|end read parquet dir,record_cnt=1278996
# 2019-10-21 16:03:19,823|INFO|nbc_analysis.dims.main|start sort by event timestamp
# 2019-10-21 16:03:22,612|INFO|nbc_analysis.dims.main|end sort by event timestamp
# 2019-10-21 16:03:22,613|INFO|nbc_analysis.dims.main|start clean input
# 2019-10-21 16:03:23,922|INFO|nbc_analysis.dims.main|event standardize null representations
# 2019-10-21 16:03:27,975|INFO|nbc_analysis.dims.main|event filter video id
# 2019-10-21 16:03:28,665|INFO|nbc_analysis.dims.main|event convert measures to float
# 2019-10-21 16:03:29,587|INFO|nbc_analysis.dims.main|event fill string nulls
# ...

# %%
outdir = Path(cfg['normalize_d'])

# %%
list(outdir.glob('*'))
# Out:
# [PosixPath('/Users/wmcabee/DATA/NBC/normalize/video_dim.parquet'),
#  PosixPath('/Users/wmcabee/DATA/NBC/normalize/end_type_dim.parquet'),
#  PosixPath('/Users/wmcabee/DATA/NBC/normalize/profile_dim.parquet'),
#  PosixPath('/Users/wmcabee/DATA/NBC/normalize/event_type_dim.parquet'),
#  PosixPath('/Users/wmcabee/DATA/NBC/normalize/platform_dim.parquet'),
#  PosixPath('/Users/wmcabee/DATA/NBC/normalize/f_video_end.parquet'),
#  PosixPath('/Users/wmcabee/DATA/NBC/normalize/day_utc_keys.parquet')]

# %%
fact = read_parquet(name='f_video_end',indir=outdir)
# Out:
# 2019-10-21 16:09:46,517|INFO|nbc_analysis.utils.file_utils|start read file,/Users/wmcabee/DATA/NBC/normalize/f_video_end.parquet
# 2019-10-21 16:09:47,587|INFO|nbc_analysis.utils.file_utils|end read file,/Users/wmcabee/DATA/NBC/normalize/f_video_end.parquet,record_cnt=1278828

# %%
fact
# Out:
#          day_utc_key             video_key          platform_key  \
# 0           20191002   7127691860878554533  13512958757101649953
# 1           20191001  14483795621015106162  16889002418789577125
# 2           20191001   4075879265284305280  13512958757101649953
# 3           20191001   3909306528269457681  16889002418789577125
# 4           20191001  18023354037711798826  13512958757101649953
# ...              ...                   ...                   ...
# 1278823     20180610   9143283662505766697   2356253770914521728
# 1278824     20180605  10908490215690080094   2356253770914521728
# 1278825     20180531  10993872243584317325   2356253770914521728
# 1278826     20180531  10993872243584317325   2356253770914521728
# 1278827     20180523  10908490215690080094   2356253770914521728
#
#                   profile_key          end_type_key             event_key  \
# 0         5612241246451325071   1543738608339601720  10286261140990397066
# ...

# %%
fact.mpid.nunique() * 60
# Out:
# 7692120

# %%
dim = read_parquet(name='profile_dim',indir=outdir)
# Out:
# 2019-10-21 16:10:13,075|INFO|nbc_analysis.utils.file_utils|start read file,/Users/wmcabee/DATA/NBC/normalize/profile_dim.parquet
# 2019-10-21 16:10:13,081|INFO|nbc_analysis.utils.file_utils|end read file,/Users/wmcabee/DATA/NBC/normalize/profile_dim.parquet,record_cnt=555

# %%
df = dim.copy()
df['record_cnt']=1
dx = df.set_index(['mvpd','nbc_profile']).record_cnt.unstack()

with pd.option_context('max_rows',None):
    display(dx)
# Out:
# nbc_profile                                      Free  Not Set  \
# mvpd
# ALLO Communications                               NaN      NaN
# ANTIETAM                                          NaN      NaN
# AT&T TV                                           1.0      NaN
# AT&T U-verse                                      1.0      1.0
# ATMC                                              NaN      NaN
# ATT                                               1.0      1.0
# ATTOTT                                            1.0      1.0
# All West Communications                           NaN      NaN
# Allen's Communications                            NaN      NaN
# American Community Networks                       NaN      NaN
# Amherst Telephone/Tomorrow Valley                 NaN      NaN
# Antietam Cable Television                         NaN      NaN
# Armstrong                                         NaN      NaN
# Arvig                                             NaN      NaN
# ...
