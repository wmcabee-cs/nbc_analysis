# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from nbc_analysis.utils.config_utils import get_config
from pathlib import Path
from toolz import take, partial
import pandas as pd
import numpy as np
from pandas_summary import DataFrameSummary
from collections import defaultdict
import itertools
from pandas.util import hash_array, hash_pandas_object

# %%
CONFIG = get_config(config='default')
SOURCE_D = Path(CONFIG['WORK_D']) / 'query'
WORK_D = Path(CONFIG['WORK_D']) / 'ip_model'
CONFIG
# Out:
# 2019-10-18 19:07:39,567|WARNING|nbc_analysis.utils.config_utils|The 'default' config is intended for testing only. For production, use /Users/wmcabee/.config/nbc_analysis/config.yaml
# {'CALENDAR_START_DAY_KEY': '20170101',
#  'CALENDAR_END_DAY_KEY': '20210101',
#  'CALENDAR_D': '/Users/wmcabee/DATA/NBC/calendar',
#  'ANALYSIS_D': '/Users/wmcabee/DATA/NBC/ana',
#  'RUNS_D': '/Users/wmcabee/DATA/NBC/runs',
#  'WORK_D': '/Users/wmcabee/DATA/NBC/work',
#  'VIDEO_END_BUCKET': 'nbc-event',
#  'VIDEO_END_PARTITIONS_BUCKET': 'nbc-partitions-video-end-protect',
#  'GEN_PROFILE_SOURCE': 'nbc-partitions-video-end',
#  'BATCH_SIZE': 200000000,
#  'GEOLITE2_DB': '/Users/wmcabee/DATA/NBC/datasets/GeoLite2-City_20191001/GeoLite2-City.mmdb',
#  'VIEWER_SOURCE_BUCKET': 'nbc-events-partitioned',
#  'VIEWER_PARTITION_COUNT': 60,
#  'VIEWER_PARTITION_D': '/Users/wmcabee/DATA/NBC/viewer_partitions',
#  'LIMIT_FILES_PER_DAY': 20,
#  'BATCH_LIMIT': 2,
#  'BATCH_FILES_LIMIT': 2,
#  'MERGE_LIMIT': 2,
#  'PROFILE_PER_WEEK_LIMIT': 1000}

# %%
reader = SOURCE_D.glob('*')
reader = take(3, reader)
df = pd.concat(map(pd.read_parquet, reader))
DATA = df.sort_values('event_start_unixtime_ms', ascending=False).reset_index(drop=True)
DATA.head(3).T
# Out:
#                                                                 0  \
# batch_id                                         ve_20190930_0003
# file                       NBC_App_20190930033852328226_68559.txt
# file_idx                                                     1532
# asof_dt                               2019-10-11T19:16:54.139463Z
# mpid                                          7752839992563167640
# nbc_profile                                       Unauthenticated
# mvpd                                              Unauthenticated
# event_name                                              Video End
# event_type                                           custom_event
# platform                                                  Not Set
# data_connection_type                                      Not Set
# ip                          2603:9001:3d0b:6300:849:27f1:5264:f16
# video_id                                                  4036451
# video_type                                              Highlight
# show                                                 Chicago P.D.
# season                                                          7
# episode_number                                                  1
# episode_title                             You Went Behind My Back
# genre                                                       Drama
# video_duration                                                  1
# video_end_type                                              Close
# resume                                                      False
# event_id                                     -2165054904579433498
# session_id                                    9025237351300304311
# video_duration_watched                          0.766666666666667
# event_start_unixtime_ms                             1569987267779
# session_start_unixtime_ms                           1569986197038
# resume_time                                                  None
# viewer_partition                                                0
#
#                                                                  1  \
# batch_id                                          ve_20191001_0004
# file                            NBC_20191001045954961424_64260.txt
# file_idx                                                      2017
# asof_dt                                2019-10-11T19:36:20.621381Z
# mpid                                           1074643952692953660
# nbc_profile                                        Unauthenticated
# mvpd                                                           DTV
# event_name                                               Video End
# event_type                                            custom_event
# platform                                                      tvOS
# data_connection_type                                          wifi
# ip                         2600:6c67:207f:f473:48a5:57d4:5c68:ce06
# video_id                                                   3675825
# video_type                                            Full Episode
# show                                                      A.P. Bio
# season                                                           1
# episode_number                                                   5
# episode_title                                     Dating Toledoans
# genre                                                       Comedy
# video_duration                                                  22
# video_end_type                                               Close
# resume                                                       False
# event_id                                      -7801022097402524755
# session_id                                     1222968412423828282
# video_duration_watched                                          22
# event_start_unixtime_ms                              1569905923977
# session_start_unixtime_ms                            1569898352051
# resume_time                                                   None
# viewer_partition                                                 0
#
#                                                                            2
# batch_id                                                    ve_20191001_0004
# file                                  NBC_App_20191001045930779268_51913.txt
# file_idx                                                                2015
# asof_dt                                          2019-10-11T19:36:20.621381Z
# mpid                                                    -7141178299446626700
# nbc_profile                                                  Unauthenticated
# mvpd                                                         Unauthenticated
# event_name                                                         Video End
# event_type                                                      custom_event
# platform                                                             Not Set
# data_connection_type                                                 Not Set
# ip                                                             66.165.21.179
# video_id                                                             4037285
# video_type                                                   Current Preview
# show                                                     Saturday Night Live
# season                                                                    45
# episode_number                                                             1
# episode_title              Saturday Is a Big Night for Woody Harrelson an...
# genre                                                                 Comedy
# video_duration                                                             1
# video_end_type                                                         Close
# resume                                                                 False
# event_id                                                -7502478291025245391
# session_id                                               6659201435104007237
# video_duration_watched                                                     0
# event_start_unixtime_ms                                        1569905885966
# session_start_unixtime_ms                                      1569903139264
# resume_time                                                             None
# viewer_partition                                                           0

# %%
def build_video_dim(data):
    
    ts_col = 'event_start_unixtime_ms'
    nk ='video_id'
    cols = ['video_type','show','season','episode_number','episode_title','genre','video_duration']

    replace_null_with = 'Not Set'

    ucols  = [nk] + cols
    dcols = ucols + [ts_col]
    

    df = data[data.video_id.notnull()]  # filter out records where video_id is null
    
    df = df[dcols].drop_duplicates(nk)
    df = df.fillna(replace_null_with)
    dim = df

    assert len(dim) == dim[nk].nunique(), "mismatch: %s != %s" % (len(dim), dim[nk].nunique())
    data.drop(columns=cols, inplace=True)
    data[nk] = data.pop(nk)
    return dim, data

# %%
DEFAULT_NA ='Not Set'

def build_hash_dim(data, hash_code, cols, upd_ts, fill_na=':ALL', na_val=DEFAULT_NA):

    dcols = [hash_code] + cols
    data[hash_code] = hash_pandas_object(data[cols], index=False).values
    dim = data[dcols].drop_duplicates().sort_values(cols)
    
    data.drop(columns=cols, inplace=True)
    if fill_na:
        if fill_na == ':ALL':
            dim[cols] = dim[cols].fillna(na_val)
        else:
            dim[fill_na] = dim[fill_na].fillna(na_val)
    return dim, data

upd_ts = 'event_start_unixtime_ms'

build_event_type_dim = partial(build_hash_dim, hash_code='event_hash', cols=['event_name', 'event_type'], upd_ts=upd_ts)
build_platform_dim = partial(build_hash_dim, hash_code='platform_hash', cols=['platform','data_connection_type'], upd_ts=upd_ts)
build_profile_dim = partial(build_hash_dim, hash_code='profile_hash', cols=['mvpd','nbc_profile'], upd_ts=upd_ts)
build_end_type_dim = partial(build_hash_dim, hash_code='end_type_hash', cols=['video_end_type','resume'], upd_ts=upd_ts)

# %%
def build_unique_set(data, cols):
    values = data[cols].drop_duplicates().sort_values(cols)
    for field in cols:
        data[field] = data.pop(field)
    return values, data

build_ip_set = partial(build_unique_set, cols=['ip'])

# %%
def clean_fact(data):
    treat_as_null = {'None','Not Set', ''}


    data = data.mask(data.isin(treat_as_null)) # Replace all null representations with np.NaN
    data['mpid'] = data.pop('mpid')

    data.drop(columns=['session_start_unixtime_ms', 'session_id'], inplace=True)
    
    return data

# %%
def set_ts_fields(data):
    
    ts = data['event_start_unixtime_ms'].astype(np.int)
    ts = ts / 1000
    ts = pd.to_datetime(ts, unit='s', origin='unix')

    data['_asof_dt'] = data.pop('asof_dt')
    data['_last_upd_dt'] =np.datetime_as_string(ts, timezone='UTC',unit='us' )
    data['day_utc_key'] = ts.dt.strftime('%Y%m%d')
    dim = data['day_utc_key'].drop_duplicates
    return dim, data

# %%
data = DATA.copy()
data = clean_fact(data)
days_dim, data = set_ts_fields(data)


ip_set, data = build_ip_set(data)
end_type_dim, data = build_end_type_dim(data)
platform_dim, data = build_platform_dim(data)
event_type_dim, data = build_event_type_dim(data)
profile_dim, data = build_profile_dim(data)
video_dim, data = build_video_dim(data)
data = data.reset_index(drop=True)

data.head().T
# Out:
#                                                               0  \
# batch_id                                       ve_20190930_0003
# file                     NBC_App_20190930033852328226_68559.txt
# file_idx                                                   1532
# event_id                                   -2165054904579433498
# video_duration_watched                        0.766666666666667
# event_start_unixtime_ms                           1569987267779
# resume_time                                                 NaN
# viewer_partition                                              0
# mpid                                        7752839992563167640
# _asof_dt                            2019-10-11T19:16:54.139463Z
# _last_upd_dt                        2019-10-02T03:34:27.779000Z
# day_utc_key                                            20191002
# ip                        2603:9001:3d0b:6300:849:27f1:5264:f16
# end_type_hash                               1543738608339601720
# platform_hash                               3713088491974073233
# event_hash                                 10286261140990397066
# profile_hash                                5612241246451325071
# video_id                                                4036451
#
#                                                                1  \
# batch_id                                        ve_20191001_0004
# file                          NBC_20191001045954961424_64260.txt
# file_idx                                                    2017
# event_id                                    -7801022097402524755
# video_duration_watched                                        22
# event_start_unixtime_ms                            1569905923977
# resume_time                                                  NaN
# viewer_partition                                               0
# mpid                                         1074643952692953660
# _asof_dt                             2019-10-11T19:36:20.621381Z
# _last_upd_dt                         2019-10-01T04:58:43.976999Z
# day_utc_key                                             20191001
# ip                       2600:6c67:207f:f473:48a5:57d4:5c68:ce06
# end_type_hash                                1543738608339601720
# platform_hash                               16889002418789577125
# event_hash                                  10286261140990397066
# profile_hash                                13998642882195919910
# video_id                                                 3675825
#
#                                                               2  \
# batch_id                                       ve_20191001_0004
# file                     NBC_App_20191001045930779268_51913.txt
# file_idx                                                   2015
# event_id                                   -7502478291025245391
# video_duration_watched                                        0
# event_start_unixtime_ms                           1569905885966
# resume_time                                                 NaN
# viewer_partition                                              0
# mpid                                       -7141178299446626700
# _asof_dt                            2019-10-11T19:36:20.621381Z
# _last_upd_dt                        2019-10-01T04:58:05.966000Z
# day_utc_key                                            20191001
# ip                                                66.165.21.179
# end_type_hash                               1543738608339601720
# platform_hash                               3713088491974073233
# event_hash                                 10286261140990397066
# profile_hash                                5612241246451325071
# video_id                                                4037285
#
#                                                           3  \
# batch_id                                   ve_20191001_0004
# file                     NBC_20191001045915679915_21786.txt
# file_idx                                               2012
# event_id                               -4125335981896278535
# video_duration_watched                                    2
# event_start_unixtime_ms                       1569905870180
# resume_time                                             NaN
# viewer_partition                                          0
# mpid                                   -2327248636060088100
# _asof_dt                        2019-10-11T19:36:20.621381Z
# _last_upd_dt                    2019-10-01T04:57:50.180000Z
# day_utc_key                                        20191001
# ip                                             64.191.7.205
# end_type_hash                           1543738608339601720
# platform_hash                          16889002418789577125
# event_hash                             10286261140990397066
# profile_hash                            5894746954545069528
# video_id                                            4001075
#
#                                                               4
# batch_id                                       ve_20191001_0004
# file                     NBC_App_20191001045937759921_60697.txt
# file_idx                                                   2016
# event_id                                   -5859414957082708798
# video_duration_watched                         2.11666666666667
# event_start_unixtime_ms                           1569905870172
# resume_time                                                 NaN
# viewer_partition                                              0
# mpid                                       -7141178299446626700
# _asof_dt                            2019-10-11T19:36:20.621381Z
# _last_upd_dt                        2019-10-01T04:57:50.171999Z
# day_utc_key                                            20191001
# ip                                                66.165.21.179
# end_type_hash                               1543738608339601720
# platform_hash                               3713088491974073233
# event_hash                                 10286261140990397066
# profile_hash                                5612241246451325071
# video_id                                                4039074

# %%
dim = video_dim
print('len:', len(dim))
dim
# Out:
# len: 11472
#        video_id       video_type                  show season episode_number  \
# 0       4036451        Highlight          Chicago P.D.      7              1
# 1       3675825     Full Episode              A.P. Bio      1              5
# 2       4037285  Current Preview   Saturday Night Live     45              1
# 3       4001075     Full Episode          Chicago P.D.      6              1
# 4       4039074        Highlight   Saturday Night Live     45              1
# ...         ...              ...                   ...    ...            ...
# 239395  3688923     Full Episode          Will & Grace      1             15
# 239396  3783035     Full Episode     Days of our Lives     53            235
# 239398  3776487     Full Episode      NBC Nightly News   2018            240
# 239400  3768292     Full Episode  America's Got Talent     13             10
# 239402  3741111     Full Episode  America's Got Talent     13              3
#
#                                             episode_title  \
# 0                                 You Went Behind My Back
# 1                                        Dating Toledoans
# 2       Saturday Is a Big Night for Woody Harrelson an...
# 3                                              New Normal
# 4               Weekend Update: Disney World’s Vegan Menu
# ...                                                   ...
# 239395                                            One Job
# 239396                            Monday, August 27, 2018
# 239398                     NBC Nightly News, Aug 24, 2018
# 239400                                       Judge Cuts 3
# 239402                                        Auditions 3
#
#                         genre video_duration event_start_unixtime_ms
# 0                       Drama              1           1569987267779
# 1                      Comedy             22           1569905923977
# 2                      Comedy              1           1569905885966
# 3                       Drama             41           1569905870180
# 4                      Comedy              2           1569905870172
# ...                       ...            ...                     ...
# 239395                 Comedy             22           1536380862782
# 239396                  Drama             37           1535447009628
# 239398   News and Information             21           1535242752057
# 239400  Reality and Game Show             84           1533167971741
# 239402  Reality and Game Show             84           1531616309347
#
# [11472 rows x 9 columns]

# %%
data['end_type_hash'].value_counts()
# Out:
# 1543738608339601720     77999
# 14134703689083528527    63491
# 10155504590337046581    47014
# 7968799331887820946     39849
# 15654977777582709682     5658
# 3037280689985078357      4778
# 13058633064681211906      259
# 14279567677105438984      218
# 3756609792117231457        89
# 6152596211329002182        39
# 6132961493477577762        29
# 17510052516783454175        1
# Name: end_type_hash, dtype: int64
