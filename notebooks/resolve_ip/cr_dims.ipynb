# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from nbc_analysis.utils.debug_utils import runit
from pathlib import Path
from toolz import take, partial
import pandas as pd
import numpy as np
from pandas_summary import DataFrameSummary
from nbc_analysis.dims.main import main as build_dims
from nbc_analysis.utils.toml_utils import get_config
from nbc_analysis.utils.file_utils import read_parquet
from toolz import assoc

# %%
config = get_config('test')
CFG = config['normalize']
CFG
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ad6d151385be> in <module>
# ----> 1 config = get_config('test')
#       2 CFG = config['normalize']
#       3 CFG
#
# NameError: name 'get_config' is not defined

# %%
# %%time
cfg = assoc(CFG,'input_file_limit', None)
df = runit(build_dims,cfg=cfg)
# Out:
# 2019-10-22 07:00:27,122|INFO|nbc_analysis.dims.main|start normalize video end, {'test_input_d': '/Users/wmcabee/DATA/NBC/work/query', 'normalize_d': '/Users/wmcabee/DATA/NBC/normalize', 'input_file_limit': None}
# 2019-10-22 07:00:27,129|INFO|nbc_analysis.utils.file_utils|start read parquet dir,file_cnt=12,limit=None
# 2019-10-22 07:00:30,217|INFO|nbc_analysis.utils.file_utils|end read parquet dir,record_cnt=1278996
# 2019-10-22 07:00:30,218|INFO|nbc_analysis.dims.main|start sort by event timestamp
# 2019-10-22 07:00:33,405|INFO|nbc_analysis.dims.main|end sort by event timestamp
# 2019-10-22 07:00:33,406|INFO|nbc_analysis.dims.main|start clean input
# 2019-10-22 07:00:34,841|INFO|nbc_analysis.dims.main|event standardize null representations
# 2019-10-22 07:00:38,367|INFO|nbc_analysis.dims.main|event filter video id
# 2019-10-22 07:00:38,956|INFO|nbc_analysis.dims.main|event convert measures to float
# 2019-10-22 07:00:39,736|INFO|nbc_analysis.dims.main|event fill string nulls
# 2019-10-22 07:00:41,254|INFO|nbc_analysis.dims.main|end clean input
# 2019-10-22 07:00:41,323|INFO|nbc_analysis.dims.main|start derive timestamp information
# 2019-10-22 07:00:41,324|INFO|nbc_analysis.dims.main|event convert _last_upd_dt to date time
# 2019-10-22 07:00:49,022|INFO|nbc_analysis.dims.main|event format event_start_dt
# 2019-10-22 07:00:57,617|INFO|nbc_analysis.dims.main|event format date_utc_key
# 2019-10-22 07:01:05,685|INFO|nbc_analysis.dims.main|event dedup date keys
# 2019-10-22 07:01:06,174|INFO|nbc_analysis.dims.main|end derive timestamp information
# 2019-10-22 07:01:06,180|INFO|nbc_analysis.utils.file_utils|start write file,/Users/wmcabee/DATA/NBC/normalize/day_utc_keys.parquet,record_cnt=397
# 2019-10-22 07:01:06,183|INFO|nbc_analysis.utils.file_utils|end write file,/Users/wmcabee/DATA/NBC/normalize/day_utc_keys.parquet,record_cnt=397
# 2019-10-22 07:01:06,183|INFO|nbc_analysis.dims.main|start collect ip addresses
# 2019-10-22 07:01:06,904|INFO|nbc_analysis.utils.file_utils|start write file,/Users/wmcabee/DATA/NBC/normalize/ips.parquet,record_cnt=226596
# 2019-10-22 07:01:06,967|INFO|nbc_analysis.utils.file_utils|end write file,/Users/wmcabee/DATA/NBC/normalize/ips.parquet,record_cnt=226596
# 2019-10-22 07:01:06,968|INFO|nbc_analysis.dims.main|end collect ip addresses
# 2019-10-22 07:01:06,969|INFO|nbc_analysis.dims.main|start build dimensions
# 2019-10-22 07:01:06,970|INFO|nbc_analysis.dims.main|start build dimensions
# 2019-10-22 07:01:07,923|INFO|nbc_analysis.utils.file_utils|start write file,/Users/wmcabee/DATA/NBC/normalize/video_dim.parquet,record_cnt=23559
# 2019-10-22 07:01:07,962|INFO|nbc_analysis.utils.file_utils|end write file,/Users/wmcabee/DATA/NBC/normalize/video_dim.parquet,record_cnt=23559
# 2019-10-22 07:01:08,355|INFO|nbc_analysis.utils.file_utils|start write file,/Users/wmcabee/DATA/NBC/normalize/event_type_dim.parquet,record_cnt=1
# 2019-10-22 07:01:08,358|INFO|nbc_analysis.utils.file_utils|end write file,/Users/wmcabee/DATA/NBC/normalize/event_type_dim.parquet,record_cnt=1
# 2019-10-22 07:01:08,779|INFO|nbc_analysis.utils.file_utils|start write file,/Users/wmcabee/DATA/NBC/normalize/platform_dim.parquet,record_cnt=11
# 2019-10-22 07:01:08,782|INFO|nbc_analysis.utils.file_utils|end write file,/Users/wmcabee/DATA/NBC/normalize/platform_dim.parquet,record_cnt=11
# 2019-10-22 07:01:09,167|INFO|nbc_analysis.utils.file_utils|start write file,/Users/wmcabee/DATA/NBC/normalize/profile_dim.parquet,record_cnt=555
# 2019-10-22 07:01:09,171|INFO|nbc_analysis.utils.file_utils|end write file,/Users/wmcabee/DATA/NBC/normalize/profile_dim.parquet,record_cnt=555
# 2019-10-22 07:01:09,533|INFO|nbc_analysis.utils.file_utils|start write file,/Users/wmcabee/DATA/NBC/normalize/end_type_dim.parquet,record_cnt=13
# 2019-10-22 07:01:09,536|INFO|nbc_analysis.utils.file_utils|end write file,/Users/wmcabee/DATA/NBC/normalize/end_type_dim.parquet,record_cnt=13
# 2019-10-22 07:01:09,537|INFO|nbc_analysis.dims.main|end build dimensions
# 2019-10-22 07:01:09,742|INFO|nbc_analysis.utils.file_utils|start write file,/Users/wmcabee/DATA/NBC/normalize/f_video_end.parquet,record_cnt=1278828
# 2019-10-22 07:01:10,880|INFO|nbc_analysis.utils.file_utils|end write file,/Users/wmcabee/DATA/NBC/normalize/f_video_end.parquet,record_cnt=1278828
# 2019-10-22 07:01:10,881|INFO|nbc_analysis.dims.main|end normalize video end
# CPU times: user 41.9 s, sys: 3.54 s, total: 45.5 s
# Wall time: 43.9 s

# %%
df
# Out:
#                     ip
# 169053    1.52.107.147
# 184326  10.101.233.130
# 45470    10.104.24.136
# 92399     10.107.80.61
# 33354      10.218.9.30
# ...                ...
# 79280      99.98.219.9
# 190114    99.98.34.157
# 75976      99.98.65.93
# 135325   99.99.137.108
# 64521      99.99.19.39
#
# [41549 rows x 1 columns]

# %%
outdir = Path(cfg['normalize_d'])

# %%
list(outdir.glob('*'))
# Out:
# [PosixPath('/Users/wmcabee/DATA/NBC/normalize/video_dim.parquet'),
#  PosixPath('/Users/wmcabee/DATA/NBC/normalize/end_type_dim.parquet'),
#  PosixPath('/Users/wmcabee/DATA/NBC/normalize/profile_dim.parquet'),
#  PosixPath('/Users/wmcabee/DATA/NBC/normalize/event_type_dim.parquet'),
#  PosixPath('/Users/wmcabee/DATA/NBC/normalize/platform_dim.parquet'),
#  PosixPath('/Users/wmcabee/DATA/NBC/normalize/f_video_end.parquet'),
#  PosixPath('/Users/wmcabee/DATA/NBC/normalize/day_utc_keys.parquet')]

# %%
fact = read_parquet(name='f_video_end',indir=outdir)
# Out:
# 2019-10-21 16:09:46,517|INFO|nbc_analysis.utils.file_utils|start read file,/Users/wmcabee/DATA/NBC/normalize/f_video_end.parquet
# 2019-10-21 16:09:47,587|INFO|nbc_analysis.utils.file_utils|end read file,/Users/wmcabee/DATA/NBC/normalize/f_video_end.parquet,record_cnt=1278828

# %%
fact
# Out:
#          day_utc_key             video_key          platform_key  \
# 0           20191002   7127691860878554533  13512958757101649953
# 1           20191001  14483795621015106162  16889002418789577125
# 2           20191001   4075879265284305280  13512958757101649953
# 3           20191001   3909306528269457681  16889002418789577125
# 4           20191001  18023354037711798826  13512958757101649953
# ...              ...                   ...                   ...
# 1278823     20180610   9143283662505766697   2356253770914521728
# 1278824     20180605  10908490215690080094   2356253770914521728
# 1278825     20180531  10993872243584317325   2356253770914521728
# 1278826     20180531  10993872243584317325   2356253770914521728
# 1278827     20180523  10908490215690080094   2356253770914521728
#
#                   profile_key          end_type_key             event_key  \
# 0         5612241246451325071   1543738608339601720  10286261140990397066
# 1        13998642882195919910   1543738608339601720  10286261140990397066
# 2         5612241246451325071   1543738608339601720  10286261140990397066
# 3         5894746954545069528   1543738608339601720  10286261140990397066
# 4         5612241246451325071   1543738608339601720  10286261140990397066
# ...                       ...                   ...                   ...
# 1278823   5612241246451325071   1543738608339601720  10286261140990397066
# 1278824   5612241246451325071  14134703689083528527  10286261140990397066
# 1278825  13998642882195919910  10155504590337046581  10286261140990397066
# 1278826  13998642882195919910  14134703689083528527  10286261140990397066
# 1278827   5612241246451325071  10155504590337046581  10286261140990397066
#
#                                               ip                 mpid  \
# 0          2603:9001:3d0b:6300:849:27f1:5264:f16  7752839992563167640
# 1        2600:6c67:207f:f473:48a5:57d4:5c68:ce06  1074643952692953660
# 2                                  66.165.21.179 -7141178299446626700
# 3                                   64.191.7.205 -2327248636060088100
# 4                                  66.165.21.179 -7141178299446626700
# ...                                          ...                  ...
# 1278823                             75.80.180.17 -8774713970552652540
# 1278824   2601:805:8400:5f80:d84d:e7c1:6d89:e5cd  3695306078025802680
# 1278825  2600:100d:b15e:af14:2c67:706f:4b85:9402  4258592002975073880
# 1278826  2600:100d:b15e:af14:2c67:706f:4b85:9402  4258592002975073880
# 1278827                            12.232.82.154 -2302969021960323660
#
#                   event_start_dt  video_duration_watched  resume_time  \
# 0        20191002T033427.779000Z                0.766667          NaN
# 1        20191001T045843.976999Z               22.000000          NaN
# 2        20191001T045805.966000Z                0.000000          NaN
# 3        20191001T045750.180000Z                2.000000          NaN
# 4        20191001T045750.171999Z                2.116667          NaN
# ...                          ...                     ...          ...
# 1278823  20180610T120844.604000Z               37.000000          NaN
# 1278824  20180605T011358.690000Z               85.000000       1495.0
# 1278825  20180531T001316.165999Z               43.000000       1014.0
# 1278826  20180531T001314.937999Z               43.000000       1014.0
# 1278827  20180523T095836.430000Z               74.000000       4705.0
#
#                                           _file  _file_idx         _batch_id  \
# 0        NBC_App_20190930033852328226_68559.txt       1532  ve_20190930_0003
# 1            NBC_20191001045954961424_64260.txt       2017  ve_20191001_0004
# 2        NBC_App_20191001045930779268_51913.txt       2015  ve_20191001_0004
# 3            NBC_20191001045915679915_21786.txt       2012  ve_20191001_0004
# 4        NBC_App_20191001045937759921_60697.txt       2016  ve_20191001_0004
# ...                                         ...        ...               ...
# 1278823      NBC_20190921000335386127_90017.txt         27  ve_20190921_0000
# 1278824      NBC_20190822020624383099_08262.txt        886  ve_20190822_0001
# 1278825      NBC_20190804181638610421_44397.txt       7593  ve_20190804_0005
# 1278826      NBC_20190804181638610421_44397.txt       7593  ve_20190804_0005
# 1278827      NBC_20190716192547424809_82822.txt       6938  ve_20190716_0007
#
#          _viewer_partition   _last_upd_dt
# 0                        0  1569987267779
# 1                        0  1569905923977
# 2                        0  1569905885966
# 3                        0  1569905870180
# 4                        0  1569905870172
# ...                    ...            ...
# 1278823                  0  1528632524604
# 1278824                  0  1528161238690
# 1278825                  0  1527725596166
# 1278826                  0  1527725594938
# 1278827                  0  1527069516430
#
# [1278828 rows x 16 columns]

# %%
fact.mpid.nunique() * 60
# Out:
# 7692120

# %%
dim = read_parquet(name='profile_dim',indir=outdir)
# Out:
# 2019-10-22 07:03:12,423|INFO|nbc_analysis.utils.file_utils|start read file,/Users/wmcabee/DATA/NBC/normalize/profile_dim.parquet
# 2019-10-22 07:03:12,435|INFO|nbc_analysis.utils.file_utils|end read file,/Users/wmcabee/DATA/NBC/normalize/profile_dim.parquet,record_cnt=555

# %%
dim
# Out:
#               profile_key                    mvpd      nbc_profile  \
# 0     1738563343610995978     ALLO Communications  Unauthenticated
# 1     4945637187593636945                ANTIETAM  Unauthenticated
# 2     1182019596081314334                 AT&T TV             Free
# 3    16817044815035191849                 AT&T TV  Unauthenticated
# 4     8202383656158745726            AT&T U-verse             Free
# ..                    ...                     ...              ...
# 550  13963434255354510353                  wtc010  Unauthenticated
# 551  15683843996944675444  www_websso_mybrctv_com             Free
# 552  13735778854231012090  www_websso_mybrctv_com          Not Set
# 553   5228453594746799603  www_websso_mybrctv_com  Unauthenticated
# 554   2992888879010180418                  yondoo  Unauthenticated
#
#       _last_upd_dt
# 0    1569770205752
# 1    1569884387287
# 2    1569901718432
# 3    1569905181319
# 4    1569877374782
# ..             ...
# 550  1569871061045
# 551  1569294078530
# 552  1568242196853
# 553  1569849121597
# 554  1569494313503
#
# [555 rows x 4 columns]
