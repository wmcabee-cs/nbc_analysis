# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from test_extract_file_lists import test_get_config, test_extract_file_lists
import numpy as np
import pandas as pd
from pandas_summary import DataFrameSummary
from toolz import concatv
from pathlib import Path
from nbc_analysis.utils.debug_utils import runit

# %%
CONFIG_F = 'default'
config= runit(test_get_config)
config
# Out:
# >> created example config file '/Users/wmcabee/.config/nbc_analysis/config_example.yaml'
# >> Using default config
# {'VIDEO_END_BUCKET': 'nbc-event',
#  'BATCHES_D': '/Users/wmcabee/DATA/NBC2/batches',
#  'FILE_LISTS_D': '/Users/wmcabee/DATA/NBC2/file_lists',
#  'BATCH_SPEC_D': '/Users/wmcabee/DATA/NBC2/batch_spec',
#  'PARTITIONS_D': '/Users/wmcabee/DATA/NBC2/partitions',
#  'BATCH_SIZE': 200000000,
#  'DAYS_LIMIT': 2,
#  'LIMIT_FILES_PER_DAY': None,
#  'LIMIT_FILE_LISTS': None,
#  'BATCH_LIMIT': 2,
#  'BATCH_FILES_LIMIT': 2}

# %%
ret = runit(test_extract_file_lists)
ret
# Out:
# >> created example config file '/Users/wmcabee/.config/nbc_analysis/config_example.yaml'
# >> Using default config
# >> created example config file '/Users/wmcabee/.config/nbc_analysis/config_example.yaml'
# >> Using default config
# >> start extract_file_lists , config={'VIDEO_END_BUCKET': 'nbc-event', 'BATCHES_D': '/Users/wmcabee/DATA/NBC2/batches', 'FILE_LISTS_D': '/Users/wmcabee/DATA/NBC2/file_lists', 'BATCH_SPEC_D': '/Users/wmcabee/DATA/NBC2/batch_spec', 'PARTITIONS_D': '/Users/wmcabee/DATA/NBC2/partitions', 'BATCH_SIZE': 200000000, 'DAYS_LIMIT': 7, 'BATCH_LIMIT': 2, 'BATCH_FILES_LIMIT': 2}, day_cnt=7
# >> wrote /Users/wmcabee/DATA/NBC2/file_lists/ve_20190701.csv.gz,cnt=8403
# >> wrote /Users/wmcabee/DATA/NBC2/file_lists/ve_20190702.csv.gz,cnt=8548
# >> wrote /Users/wmcabee/DATA/NBC2/file_lists/ve_20190703.csv.gz,cnt=8548
# >> wrote /Users/wmcabee/DATA/NBC2/file_lists/ve_20190704.csv.gz,cnt=8571
# >> wrote /Users/wmcabee/DATA/NBC2/file_lists/ve_20190705.csv.gz,cnt=8557
# ...

# %%
indir = Path('/Users/wmcabee/DATA/NBC2/file_lists')
reader = indir.glob('ve_*')
reader = map(pd.read_csv, reader)
df = pd.concat(reader)

# %%
dfs = DataFrameSummary(df)
dfs.columns_stats.T
# Out:
#              counts uniques missing missing_perc        types
# file          16951   16951       0           0%       unique
# size          16951   16772       0           0%      numeric
# pattern_type  16951       3       0           0%  categorical
# file_dt       16951   16951       0           0%       unique
# day           16951       2       0           0%         bool
# asof_dt       16951       2       0           0%         bool

# %%
df.sample(20)
# Out:
#                                                    file     size pattern_type  \
# 489   year=2019/month=07/event=video_end/NBC_2019070...   345407      android
# 2195  year=2019/month=07/event=video_end/NBC_2019070...    90530      android
# 4783  year=2019/month=07/event=video_end/NBC_2019070...   202607      android
# 6021  year=2019/month=07/event=video_end/NBC_App_201...   225919          web
# 4563  year=2019/month=07/event=video_end/NBC_2019070...  1324817      android
# 7311  year=2019/month=07/event=video_end/NBC_App_201...   290674          web
# 5994  year=2019/month=07/event=video_end/NBC_App_201...   236934          web
# 959   year=2019/month=07/event=video_end/NBC_2019070...  1681536      android
# 7814  year=2019/month=07/event=video_end/NBC_App_201...   463343          web
# 5364  year=2019/month=07/event=video_end/NBC_App_201...   281629          web
# 1512  year=2019/month=07/event=video_end/NBC_2019070...   300041      android
# ...
