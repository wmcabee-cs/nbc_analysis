# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from nbc_analysis.utils.debug_utils import runit
from test_partition_by_viewer import test_partition_by_viewer, _get_test_config
from nbc_analysis.transforms import merge_video_ends

from pathlib import Path

import re

# %matplotlib inline

# %%
CONFIG = _get_test_config()
# Out:
# >> created example config file '/Users/wmcabee/.config/nbc_analysis/config_example.yaml'
# >> Using default config
# >> WARNING: Overriding config file values with : {'BATCHES_D': '/Users/wmcabee/Dropbox (Cognitive Scale)/NBC Analysis/data/NBC2/batches'}

# %%
# %%time 
DATA = runit(merge_video_ends,config_f=CONFIG, BATCH_MERGE_LIMIT=None, VIEWER_PARTITION_NUM=60)
DATA.head()
# Out:
# >> Loading batches,batch_cnt=129,indir=/Users/wmcabee/Dropbox (Cognitive Scale)/NBC Analysis/data/NBC2/batches
# >> finished read of batch files,files=129,records=6265392
# >> add calculated fields
# >> checking date ranges
# start_day=20190701,end_day=20190707
# >> grouping by partitions
# >> writing partitions,partition_num=60
# >> wrote viewer_partition /Users/wmcabee/DATA/NBC2/work/p000/ve_p000_20190701_20190707.parquet,records=104386
# >> wrote viewer_partition /Users/wmcabee/DATA/NBC2/work/p001/ve_p001_20190701_20190707.parquet,records=104221
# >> wrote viewer_partition /Users/wmcabee/DATA/NBC2/work/p002/ve_p002_20190701_20190707.parquet,records=101809
# >> wrote viewer_partition /Users/wmcabee/DATA/NBC2/work/p003/ve_p003_20190701_20190707.parquet,records=101549
# >> wrote viewer_partition /Users/wmcabee/DATA/NBC2/work/p004/ve_p004_20190701_20190707.parquet,records=103649
# ...

# %%
work_d = Path(CONFIG['WORK_D'])

# %%
list(work_d.glob('*/*'))
# Out:
# [PosixPath('/Users/wmcabee/DATA/NBC2/work/p018/ve_p018_20190701_20190707.parquet'),
#  PosixPath('/Users/wmcabee/DATA/NBC2/work/p027/ve_p027_20190701_20190707.parquet'),
#  PosixPath('/Users/wmcabee/DATA/NBC2/work/p020/ve_p020_20190701_20190707.parquet'),
#  PosixPath('/Users/wmcabee/DATA/NBC2/work/p029/ve_p029_20190701_20190707.parquet'),
#  PosixPath('/Users/wmcabee/DATA/NBC2/work/p016/ve_p016_20190701_20190707.parquet'),
#  PosixPath('/Users/wmcabee/DATA/NBC2/work/p011/ve_p011_20190701_20190707.parquet'),
#  PosixPath('/Users/wmcabee/DATA/NBC2/work/p045/ve_p045_20190701_20190707.parquet'),
#  PosixPath('/Users/wmcabee/DATA/NBC2/work/p042/ve_p042_20190701_20190707.parquet'),
#  PosixPath('/Users/wmcabee/DATA/NBC2/work/p010/ve_p010_20190701_20190707.parquet'),
#  PosixPath('/Users/wmcabee/DATA/NBC2/work/p028/ve_p028_20190701_20190707.parquet'),
#  PosixPath('/Users/wmcabee/DATA/NBC2/work/p017/ve_p017_20190701_20190707.parquet'),
# ...

# %%
df.head().T
# Out:
#                                                         32394  \
# batch_id                                     ve_20190706_0010
# file                       NBC_20190706150328515430_48852.txt
# file_idx                                                 5386
# asof_dt                           2019-10-01T22:29:00.313638Z
# mpid                                     -9221340724139034240
# nbc_profile                                   Unauthenticated
# mvpd                                          Unauthenticated
# event_name                                          Video End
# event_type                                       custom_event
# platform                                              Android
# data_connection_type                                     wifi
# ip                                               174.63.52.97
# video_id                                              3980296
# video_type                                       Full Episode
# ...
