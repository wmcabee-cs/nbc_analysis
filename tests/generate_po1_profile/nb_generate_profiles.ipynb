# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from test_generate_profiles import test_generate_profiles, _get_config
from nbc_analysis.utils.debug_utils import runit
import pandas as pd

from toolz import *
import re
from pathlib import Path

# %%
config = _get_config()
# Out:
# 2019-10-12 19:19:25,900|WARNING|nbc_analysis.utils.config_utils|The 'default' config is intended for testing only. For production, use /Users/wmcabee/.config/nbc_analysis/config.yaml

# %%
df = runit(test_generate_profiles)
# Out:
# 2019-10-12 19:49:22,835|WARNING|nbc_analysis.utils.config_utils|The 'default' config is intended for testing only. For production, use /Users/wmcabee/.config/nbc_analysis/config.yaml
# 2019-10-12 19:49:22,837|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,bucket_key=nbc-partitions-video-end
# 2019-10-12 19:49:22,847|INFO|nbc_analysis.generate_po1_profiles.main|start initialize_gen_profiles
# 2019-10-12 19:49:22,851|INFO|nbc_analysis.generate_po1_profiles.main|start list_clean_files
# 2019-10-12 19:49:23,508|INFO|nbc_analysis.generate_po1_profiles.main|end list_clean_files
# 2019-10-12 19:49:23,513|INFO|nbc_analysis.generate_po1_profiles.main|wrote /Users/wmcabee/DATA/NBC/work/list_clean_files.csv,records=814
# 2019-10-12 19:49:23,514|INFO|nbc_analysis.generate_po1_profiles.main|end initialize_gen_profiles
# 2019-10-12 19:49:23,526|INFO|nbc_analysis.generate_po1_profiles.main|end gen_profiles
# 2019-10-12 19:49:23,527|INFO|nbc_analysis.generate_po1_profiles.main|start proc_week,week_id=2019W40,records=19
# 2019-10-12 19:49:23,528|WARNING|nbc_analysis.utils.func_utils|merge_limit set,limit=2
# 2019-10-12 19:49:23,528|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W40/ve_20190930_0000.parquet,outfile=ve_20190930_0000.parquet
# 2019-10-12 19:49:24,355|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W40/ve_20190930_0000.parquet
# 2019-10-12 19:49:24,356|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W40/ve_20190930_0001.parquet,outfile=ve_20190930_0001.parquet
# 2019-10-12 19:49:24,857|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W40/ve_20190930_0001.parquet
# 2019-10-12 19:49:25,343|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,in_records=204368
# 2019-10-12 19:49:25,344|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 19:49:26,010|INFO|nbc_analysis.generate_po1_profiles.main|wrote file=/Users/wmcabee/DATA/NBC/work/2019W40/nbc_profile_2019W40.json.gz
# 2019-10-12 19:49:26,011|INFO|nbc_analysis.generate_po1_profiles.main|start upload_profile,key=nbc_profiles/nbc_profile_2019W40.json.gz
# 2019-10-12 19:49:26,853|INFO|nbc_analysis.generate_po1_profiles.main|end upload_profile,key=nbc_profiles/nbc_profile_2019W40.json.gz
# 2019-10-12 19:49:26,854|INFO|nbc_analysis.generate_po1_profiles.main|start clean_week,week_d=/Users/wmcabee/DATA/NBC/work/2019W40
# 2019-10-12 19:49:26,857|INFO|nbc_analysis.generate_po1_profiles.main|end proc_week,week_id=2019W40
# 2019-10-12 19:49:26,894|INFO|nbc_analysis.generate_po1_profiles.main|start proc_week,week_id=2019W39,records=106
# 2019-10-12 19:49:26,895|WARNING|nbc_analysis.utils.func_utils|merge_limit set,limit=2
# 2019-10-12 19:49:26,896|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W39/ve_20190923_0000.parquet,outfile=ve_20190923_0000.parquet
# 2019-10-12 19:49:27,301|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W39/ve_20190923_0000.parquet
# 2019-10-12 19:49:27,302|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W39/ve_20190923_0001.parquet,outfile=ve_20190923_0001.parquet
# 2019-10-12 19:49:27,754|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W39/ve_20190923_0001.parquet
# 2019-10-12 19:49:28,237|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,in_records=201532
# 2019-10-12 19:49:28,238|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 19:49:28,956|INFO|nbc_analysis.generate_po1_profiles.main|wrote file=/Users/wmcabee/DATA/NBC/work/2019W39/nbc_profile_2019W39.json.gz
# 2019-10-12 19:49:28,957|INFO|nbc_analysis.generate_po1_profiles.main|start upload_profile,key=nbc_profiles/nbc_profile_2019W39.json.gz
# 2019-10-12 19:49:29,286|INFO|nbc_analysis.generate_po1_profiles.main|end upload_profile,key=nbc_profiles/nbc_profile_2019W39.json.gz
# 2019-10-12 19:49:29,287|INFO|nbc_analysis.generate_po1_profiles.main|start clean_week,week_d=/Users/wmcabee/DATA/NBC/work/2019W39
# 2019-10-12 19:49:29,290|INFO|nbc_analysis.generate_po1_profiles.main|end proc_week,week_id=2019W39
# 2019-10-12 19:49:29,329|INFO|nbc_analysis.generate_po1_profiles.main|start proc_week,week_id=2019W38,records=73
# 2019-10-12 19:49:29,331|WARNING|nbc_analysis.utils.func_utils|merge_limit set,limit=2
# 2019-10-12 19:49:29,331|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W38/ve_20190916_0000.parquet,outfile=ve_20190916_0000.parquet
# 2019-10-12 19:49:29,828|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W38/ve_20190916_0000.parquet
# 2019-10-12 19:49:29,829|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W38/ve_20190916_0001.parquet,outfile=ve_20190916_0001.parquet
# 2019-10-12 19:49:30,337|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W38/ve_20190916_0001.parquet
# 2019-10-12 19:49:30,936|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,in_records=200368
# 2019-10-12 19:49:30,937|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 19:49:31,614|INFO|nbc_analysis.generate_po1_profiles.main|wrote file=/Users/wmcabee/DATA/NBC/work/2019W38/nbc_profile_2019W38.json.gz
# 2019-10-12 19:49:31,614|INFO|nbc_analysis.generate_po1_profiles.main|start upload_profile,key=nbc_profiles/nbc_profile_2019W38.json.gz
# 2019-10-12 19:49:31,821|INFO|nbc_analysis.generate_po1_profiles.main|end upload_profile,key=nbc_profiles/nbc_profile_2019W38.json.gz
# 2019-10-12 19:49:31,822|INFO|nbc_analysis.generate_po1_profiles.main|start clean_week,week_d=/Users/wmcabee/DATA/NBC/work/2019W38
# 2019-10-12 19:49:31,825|INFO|nbc_analysis.generate_po1_profiles.main|end proc_week,week_id=2019W38
# 2019-10-12 19:49:31,865|INFO|nbc_analysis.generate_po1_profiles.main|start proc_week,week_id=2019W37,records=70
# 2019-10-12 19:49:31,867|WARNING|nbc_analysis.utils.func_utils|merge_limit set,limit=2
# 2019-10-12 19:49:31,867|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W37/ve_20190909_0000.parquet,outfile=ve_20190909_0000.parquet
# 2019-10-12 19:49:32,390|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W37/ve_20190909_0000.parquet
# 2019-10-12 19:49:32,391|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W37/ve_20190909_0001.parquet,outfile=ve_20190909_0001.parquet
# 2019-10-12 19:49:32,912|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W37/ve_20190909_0001.parquet
# 2019-10-12 19:49:33,504|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,in_records=201096
# 2019-10-12 19:49:33,504|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 19:49:34,200|INFO|nbc_analysis.generate_po1_profiles.main|wrote file=/Users/wmcabee/DATA/NBC/work/2019W37/nbc_profile_2019W37.json.gz
# 2019-10-12 19:49:34,200|INFO|nbc_analysis.generate_po1_profiles.main|start upload_profile,key=nbc_profiles/nbc_profile_2019W37.json.gz
# 2019-10-12 19:49:34,337|INFO|nbc_analysis.generate_po1_profiles.main|end upload_profile,key=nbc_profiles/nbc_profile_2019W37.json.gz
# 2019-10-12 19:49:34,338|INFO|nbc_analysis.generate_po1_profiles.main|start clean_week,week_d=/Users/wmcabee/DATA/NBC/work/2019W37
# 2019-10-12 19:49:34,341|INFO|nbc_analysis.generate_po1_profiles.main|end proc_week,week_id=2019W37
# 2019-10-12 19:49:34,384|INFO|nbc_analysis.generate_po1_profiles.main|start proc_week,week_id=2019W36,records=68
# 2019-10-12 19:49:34,385|WARNING|nbc_analysis.utils.func_utils|merge_limit set,limit=2
# 2019-10-12 19:49:34,386|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W36/ve_20190902_0000.parquet,outfile=ve_20190902_0000.parquet
# 2019-10-12 19:49:34,876|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W36/ve_20190902_0000.parquet
# 2019-10-12 19:49:34,877|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W36/ve_20190902_0001.parquet,outfile=ve_20190902_0001.parquet
# 2019-10-12 19:49:35,365|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W36/ve_20190902_0001.parquet
# 2019-10-12 19:49:35,958|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,in_records=202664
# 2019-10-12 19:49:35,959|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 19:49:36,647|INFO|nbc_analysis.generate_po1_profiles.main|wrote file=/Users/wmcabee/DATA/NBC/work/2019W36/nbc_profile_2019W36.json.gz
# 2019-10-12 19:49:36,647|INFO|nbc_analysis.generate_po1_profiles.main|start upload_profile,key=nbc_profiles/nbc_profile_2019W36.json.gz
# 2019-10-12 19:49:36,768|INFO|nbc_analysis.generate_po1_profiles.main|end upload_profile,key=nbc_profiles/nbc_profile_2019W36.json.gz
# 2019-10-12 19:49:36,769|INFO|nbc_analysis.generate_po1_profiles.main|start clean_week,week_d=/Users/wmcabee/DATA/NBC/work/2019W36
# 2019-10-12 19:49:36,772|INFO|nbc_analysis.generate_po1_profiles.main|end proc_week,week_id=2019W36
# 2019-10-12 19:49:36,812|INFO|nbc_analysis.generate_po1_profiles.main|start proc_week,week_id=2019W35,records=67
# 2019-10-12 19:49:36,813|WARNING|nbc_analysis.utils.func_utils|merge_limit set,limit=2
# 2019-10-12 19:49:36,814|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W35/ve_20190826_0000.parquet,outfile=ve_20190826_0000.parquet
# 2019-10-12 19:49:37,329|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W35/ve_20190826_0000.parquet
# 2019-10-12 19:49:37,330|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W35/ve_20190826_0001.parquet,outfile=ve_20190826_0001.parquet
# 2019-10-12 19:49:37,888|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W35/ve_20190826_0001.parquet
# 2019-10-12 19:49:38,482|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,in_records=200050
# 2019-10-12 19:49:38,483|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 19:49:39,178|INFO|nbc_analysis.generate_po1_profiles.main|wrote file=/Users/wmcabee/DATA/NBC/work/2019W35/nbc_profile_2019W35.json.gz
# 2019-10-12 19:49:39,179|INFO|nbc_analysis.generate_po1_profiles.main|start upload_profile,key=nbc_profiles/nbc_profile_2019W35.json.gz
# 2019-10-12 19:49:39,371|INFO|nbc_analysis.generate_po1_profiles.main|end upload_profile,key=nbc_profiles/nbc_profile_2019W35.json.gz
# 2019-10-12 19:49:39,372|INFO|nbc_analysis.generate_po1_profiles.main|start clean_week,week_d=/Users/wmcabee/DATA/NBC/work/2019W35
# 2019-10-12 19:49:39,375|INFO|nbc_analysis.generate_po1_profiles.main|end proc_week,week_id=2019W35
# 2019-10-12 19:49:39,410|INFO|nbc_analysis.generate_po1_profiles.main|start proc_week,week_id=2019W34,records=68
# 2019-10-12 19:49:39,411|WARNING|nbc_analysis.utils.func_utils|merge_limit set,limit=2
# 2019-10-12 19:49:39,412|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W34/ve_20190819_0000.parquet,outfile=ve_20190819_0000.parquet
# 2019-10-12 19:49:39,908|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W34/ve_20190819_0000.parquet
# 2019-10-12 19:49:39,908|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W34/ve_20190819_0001.parquet,outfile=ve_20190819_0001.parquet
# 2019-10-12 19:49:40,403|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W34/ve_20190819_0001.parquet
# 2019-10-12 19:49:40,982|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,in_records=199173
# 2019-10-12 19:49:40,983|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 19:49:41,670|INFO|nbc_analysis.generate_po1_profiles.main|wrote file=/Users/wmcabee/DATA/NBC/work/2019W34/nbc_profile_2019W34.json.gz
# 2019-10-12 19:49:41,671|INFO|nbc_analysis.generate_po1_profiles.main|start upload_profile,key=nbc_profiles/nbc_profile_2019W34.json.gz
# 2019-10-12 19:49:41,829|INFO|nbc_analysis.generate_po1_profiles.main|end upload_profile,key=nbc_profiles/nbc_profile_2019W34.json.gz
# 2019-10-12 19:49:41,830|INFO|nbc_analysis.generate_po1_profiles.main|start clean_week,week_d=/Users/wmcabee/DATA/NBC/work/2019W34
# 2019-10-12 19:49:41,833|INFO|nbc_analysis.generate_po1_profiles.main|end proc_week,week_id=2019W34
# 2019-10-12 19:49:41,872|INFO|nbc_analysis.generate_po1_profiles.main|start proc_week,week_id=2019W33,records=70
# 2019-10-12 19:49:41,874|WARNING|nbc_analysis.utils.func_utils|merge_limit set,limit=2
# 2019-10-12 19:49:41,875|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W33/ve_20190812_0000.parquet,outfile=ve_20190812_0000.parquet
# 2019-10-12 19:49:42,442|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W33/ve_20190812_0000.parquet
# 2019-10-12 19:49:42,443|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W33/ve_20190812_0001.parquet,outfile=ve_20190812_0001.parquet
# 2019-10-12 19:49:42,927|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W33/ve_20190812_0001.parquet
# 2019-10-12 19:49:43,396|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,in_records=198339
# 2019-10-12 19:49:43,397|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 19:49:44,084|INFO|nbc_analysis.generate_po1_profiles.main|wrote file=/Users/wmcabee/DATA/NBC/work/2019W33/nbc_profile_2019W33.json.gz
# 2019-10-12 19:49:44,084|INFO|nbc_analysis.generate_po1_profiles.main|start upload_profile,key=nbc_profiles/nbc_profile_2019W33.json.gz
# 2019-10-12 19:49:44,241|INFO|nbc_analysis.generate_po1_profiles.main|end upload_profile,key=nbc_profiles/nbc_profile_2019W33.json.gz
# 2019-10-12 19:49:44,241|INFO|nbc_analysis.generate_po1_profiles.main|start clean_week,week_d=/Users/wmcabee/DATA/NBC/work/2019W33
# 2019-10-12 19:49:44,245|INFO|nbc_analysis.generate_po1_profiles.main|end proc_week,week_id=2019W33
# 2019-10-12 19:49:44,283|INFO|nbc_analysis.generate_po1_profiles.main|start proc_week,week_id=2019W32,records=66
# 2019-10-12 19:49:44,285|WARNING|nbc_analysis.utils.func_utils|merge_limit set,limit=2
# 2019-10-12 19:49:44,286|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W32/ve_20190805_0000.parquet,outfile=ve_20190805_0000.parquet
# 2019-10-12 19:49:44,747|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W32/ve_20190805_0000.parquet
# 2019-10-12 19:49:44,748|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W32/ve_20190805_0001.parquet,outfile=ve_20190805_0001.parquet
# 2019-10-12 19:49:45,224|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W32/ve_20190805_0001.parquet
# 2019-10-12 19:49:45,818|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,in_records=198086
# 2019-10-12 19:49:45,818|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 19:49:46,514|INFO|nbc_analysis.generate_po1_profiles.main|wrote file=/Users/wmcabee/DATA/NBC/work/2019W32/nbc_profile_2019W32.json.gz
# 2019-10-12 19:49:46,515|INFO|nbc_analysis.generate_po1_profiles.main|start upload_profile,key=nbc_profiles/nbc_profile_2019W32.json.gz
# 2019-10-12 19:49:46,675|INFO|nbc_analysis.generate_po1_profiles.main|end upload_profile,key=nbc_profiles/nbc_profile_2019W32.json.gz
# 2019-10-12 19:49:46,676|INFO|nbc_analysis.generate_po1_profiles.main|start clean_week,week_d=/Users/wmcabee/DATA/NBC/work/2019W32
# 2019-10-12 19:49:46,679|INFO|nbc_analysis.generate_po1_profiles.main|end proc_week,week_id=2019W32
# 2019-10-12 19:49:46,711|INFO|nbc_analysis.generate_po1_profiles.main|start proc_week,week_id=2019W31,records=67
# 2019-10-12 19:49:46,712|WARNING|nbc_analysis.utils.func_utils|merge_limit set,limit=2
# 2019-10-12 19:49:46,713|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W31/ve_20190729_0000.parquet,outfile=ve_20190729_0000.parquet
# 2019-10-12 19:49:47,187|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W31/ve_20190729_0000.parquet
# 2019-10-12 19:49:47,189|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W31/ve_20190729_0001.parquet,outfile=ve_20190729_0001.parquet
# 2019-10-12 19:49:47,654|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W31/ve_20190729_0001.parquet
# 2019-10-12 19:49:48,129|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,in_records=198880
# 2019-10-12 19:49:48,130|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 19:49:48,808|INFO|nbc_analysis.generate_po1_profiles.main|wrote file=/Users/wmcabee/DATA/NBC/work/2019W31/nbc_profile_2019W31.json.gz
# 2019-10-12 19:49:48,809|INFO|nbc_analysis.generate_po1_profiles.main|start upload_profile,key=nbc_profiles/nbc_profile_2019W31.json.gz
# 2019-10-12 19:49:48,958|INFO|nbc_analysis.generate_po1_profiles.main|end upload_profile,key=nbc_profiles/nbc_profile_2019W31.json.gz
# 2019-10-12 19:49:48,959|INFO|nbc_analysis.generate_po1_profiles.main|start clean_week,week_d=/Users/wmcabee/DATA/NBC/work/2019W31
# 2019-10-12 19:49:48,962|INFO|nbc_analysis.generate_po1_profiles.main|end proc_week,week_id=2019W31
# 2019-10-12 19:49:48,995|INFO|nbc_analysis.generate_po1_profiles.main|start proc_week,week_id=2019W30,records=71
# 2019-10-12 19:49:48,996|WARNING|nbc_analysis.utils.func_utils|merge_limit set,limit=2
# 2019-10-12 19:49:48,997|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W30/ve_20190722_0000.parquet,outfile=ve_20190722_0000.parquet
# 2019-10-12 19:49:49,463|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W30/ve_20190722_0000.parquet
# 2019-10-12 19:49:49,464|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W30/ve_20190722_0001.parquet,outfile=ve_20190722_0001.parquet
# 2019-10-12 19:49:49,954|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W30/ve_20190722_0001.parquet
# 2019-10-12 19:49:50,431|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,in_records=200141
# 2019-10-12 19:49:50,432|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 19:49:51,102|INFO|nbc_analysis.generate_po1_profiles.main|wrote file=/Users/wmcabee/DATA/NBC/work/2019W30/nbc_profile_2019W30.json.gz
# 2019-10-12 19:49:51,103|INFO|nbc_analysis.generate_po1_profiles.main|start upload_profile,key=nbc_profiles/nbc_profile_2019W30.json.gz
# 2019-10-12 19:49:51,254|INFO|nbc_analysis.generate_po1_profiles.main|end upload_profile,key=nbc_profiles/nbc_profile_2019W30.json.gz
# 2019-10-12 19:49:51,255|INFO|nbc_analysis.generate_po1_profiles.main|start clean_week,week_d=/Users/wmcabee/DATA/NBC/work/2019W30
# 2019-10-12 19:49:51,257|INFO|nbc_analysis.generate_po1_profiles.main|end proc_week,week_id=2019W30
# 2019-10-12 19:49:51,291|INFO|nbc_analysis.generate_po1_profiles.main|start proc_week,week_id=2019W29,records=69
# 2019-10-12 19:49:51,292|WARNING|nbc_analysis.utils.func_utils|merge_limit set,limit=2
# 2019-10-12 19:49:51,293|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W29/ve_20190715_0000.parquet,outfile=ve_20190715_0000.parquet
# 2019-10-12 19:49:51,778|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W29/ve_20190715_0000.parquet
# 2019-10-12 19:49:51,779|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W29/ve_20190715_0001.parquet,outfile=ve_20190715_0001.parquet
# 2019-10-12 19:49:52,262|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W29/ve_20190715_0001.parquet
# 2019-10-12 19:49:52,738|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,in_records=199938
# 2019-10-12 19:49:52,739|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 19:49:53,420|INFO|nbc_analysis.generate_po1_profiles.main|wrote file=/Users/wmcabee/DATA/NBC/work/2019W29/nbc_profile_2019W29.json.gz
# 2019-10-12 19:49:53,420|INFO|nbc_analysis.generate_po1_profiles.main|start upload_profile,key=nbc_profiles/nbc_profile_2019W29.json.gz
# 2019-10-12 19:49:53,584|INFO|nbc_analysis.generate_po1_profiles.main|end upload_profile,key=nbc_profiles/nbc_profile_2019W29.json.gz
# 2019-10-12 19:49:53,586|INFO|nbc_analysis.generate_po1_profiles.main|start clean_week,week_d=/Users/wmcabee/DATA/NBC/work/2019W29
# 2019-10-12 19:49:53,588|INFO|nbc_analysis.generate_po1_profiles.main|end proc_week,week_id=2019W29

# %%
df
# Out:
# ['#1 Single',
#  '#RichKids of Beverly Hills',
#  '1st Look',
#  '2 Lava 2 Lantula',
#  '30 Rock',
#  '47 Ronin',
#  '5-Headed Shark Attack',
#  '6-Headed Shark Attack',
#  'A Lie to Die For',
#  'A Little Late with Lilly Singh',
#  'A Madea Christmas',
#  'A Very Wicked Halloween: Celebrating 15 Years on Broadway',
#  'A Wedding and a Murder',
#  'A-List Listings',
#  'A.P. Bio',
#  'AM Joy',
#  'Aaron Hernandez Uncovered',
#  'Aaron Hernandez, McNair & Dele: Dangerous Games',
#  "Abby's",
#  'Access',
#  'Access Hollywood',
#  'After Lately',
#  'Al Rojo Vivo',
#  'Aladdin and the Death Lamp',
#  'Alien News Desk',
#  'Alien Siege',
#  'All In with Chris Hayes',
#  'Allegiance',
#  'Amazing Stories',
#  "America's Got Talent",
#  'American Greed',
#  'American Greed: Deadly Rich',
#  'American Horror House',
#  'American Ninja Warrior',
#  'American Ninja Warrior Junior',
#  'American Ninja Warrior: Ninja vs Ninja',
#  'American Swamp',
#  'Ant-Man',
#  'Arctic Predator',
#  'Ashlee+Evan',
#  'Atomica',
#  'Average Joe',
#  'Battle at Big Rock',
#  'Battlestar Galactica',
#  'Battlestar Galactica (1978)',
#  'Battlestar Galactica: The Mini-Series',
#  'Below Deck',
#  'Below Deck Mediterranean',
#  'Best Room Wins',
#  'Better Late Than Never',
#  'Beverly Hills Dog Show',
#  'Big Rich Atlanta',
#  'Big Rich Texas',
#  'Big Star Little Star',
#  'Billboard Music Awards',
#  'Blindspot',
#  'Blood Drive',
#  'Bluff City Law',
#  'Bobbi Kristina Brown: Deadly Legacy',
#  'Bobby & Iza',
#  'Boo! A Madea Halloween',
#  'Botched',
#  'Botched By Nature',
#  "Brian's Song",
#  'Bridalplasty',
#  'Bring the Funny',
#  'Brooklyn Nine-Nine',
#  'Buck Rogers in the 25th Century',
#  'Buried in the Backyard',
#  'CSI',
#  'Camera Obscura',
#  'Cash Pad',
#  'Catching Kelce',
#  'Channel Zero: The Dream Door',
#  'Charles in Charge',
#  'Chicago Fire',
#  'Chicago Med',
#  'Chicago P.D.',
#  'Chrisley Knows Best',
#  'Christina Milian Turned Up',
#  'Citizen Rose',
#  'Clean House',
#  'Cold Justice',
#  'Coming Soon to NBC ',
#  'Consumer 101',
#  'Cosplay Melee',
#  'Crimson Force',
#  'Crossbones',
#  'Cucuy: The Boogeyman',
#  'Dahmer on Dahmer: A Serial Killer Speaks',
#  'Daily Pop',
#  'Dallas Divas & Daughters',
#  'Dannemora Prison Break',
#  'Dark Relic',
#  'Dark Web Exposed',
#  'Darklight',
#  'Darkroom',
#  'Dateline',
#  'Dateline: Secrets Uncovered',
#  'Dating: No Filter',
#  'Day of Reckoning',
#  'Days of our Lives',
#  'Dead 7',
#  'Dead In The Water',
#  'Deadline: White House',
#  'Deadly Class',
#  'Deal or No Deal',
#  'Death at the Mansion: Rebecca Zahau',
#  "Denise Richards: It's Complicated",
#  'Dirty John, The Dirty Truth',
#  'Dirty Soap',
#  "Don't Be Tardy",
#  'Dracula',
#  'E! News',
#  'EJ NYC',
#  'Earth Odyssey with Dylan Dreyer',
#  'El Secreto de Selena',
#  'El Secreto de Selena (ENGLISH subs)',
#  "Ellen's Game of Games",
#  'Eric And Jessie',
#  'Escape Club',
#  'Eyewitness',
#  'Face Off',
#  'Face Off: Game Face',
#  'Famously Single',
#  'Filthy Rich: Cattle Drive',
#  'Flip It Like Disick',
#  'Flipping Exes',
#  'Friday Night Lights',
#  'Futurama',
#  'Gary and His Demons',
#  'George to the Rescue',
#  'Ghost In the Shell',
#  'Ghost in the Shell',
#  'Giuliana & Bill',
#  'Global Citizen Festival',
#  'Golden State Killer: Main Suspect',
#  'Good Girls',
#  'Growing Up Chrisley',
#  'Growing Up Fisher',
#  'Guys with Kids',
#  'Happy!',
#  'Hardball with Chris Matthews',
#  'Harry Potter and the Deathly Hallows Part 1',
#  'Harry Potter and the Deathly Hallows, Part 1',
#  'Harry Potter and the Goblet of Fire',
#  'Heroes',
#  'Heroes Reborn',
#  'Hollywood & Football',
#  'Hollywood Game Night',
#  'Hollywood Medium With Tyler Henry',
#  'Hot Listings Miami',
#  'House',
#  'House of the Witch',
#  'How Do I Look?',
#  'How Low Will You Go?',
#  'Husband for Hire',
#  'I Feel Bad',
#  'I Love Jenni (ENGLISH)',
#  'Ice Sharks',
#  'In Ice Cold Blood',
#  'Injustice with Nancy Grace',
#  'Inside the FBI: New York',
#  "Jay Leno's Garage",
#  "Jay Leno's Garage: The Digital Series",
#  'Jeepers Creepers 3',
#  'Jerseylicious',
#  'Jesus Christ Superstar Live in Concert',
#  "Jim Henson's Creature Shop Challenge",
#  'Jodi Arias: In Defense Of',
#  'Journey with Dylan Dreyer',
#  'Just Jillian',
#  'Keeping Up With The Kardashians',
#  'Kemper on Kemper: Inside the Mind of a Serial Killer',
#  'Kidnapped at the Club',
#  'Killer Affair',
#  'Killer Couples',
#  'Killer High',
#  'Killer Motive',
#  'Killing Them Softly',
#  'Killing Versace',
#  'Killjoys',
#  'Kimora: Life in the Fab Lane',
#  'Kings',
#  'Knight Rider',
#  'Knight Rider (1982)',
#  'Knight Rider (1982-1986)',
#  'Knight Rider Classic (1982-1986)',
#  'Kolchak: The Night Stalker',
#  'Krypton',
#  'L.A. Clippers Dance Squad',
#  'La Ley de Zapata',
#  'La Liga Premier',
#  'La Reina del Sur, De Película (English Subtitled)',
#  'Lady Revenge',
#  'Lake Placid: Legacy',
#  'Larrymania',
#  'Last Call with Carson Daly',
#  'Last Chance Kitchen',
#  'Late Night with Seth Meyers',
#  'Law & Order: Los Angeles',
#  'Law & Order: Special Victims Unit',
#  'Law & Order: Trial By Jury',
#  'License to Kill',
#  'Life',
#  'Lipstick Jungle',
#  'Little Big Shots',
#  'MTP Daily',
#  'Mad Money',
#  "Madea's Big Happy Family",
#  "Madea's Witness Protection",
#  'Making It',
#  'Manifest',
#  'Manson: The Women',
#  'Married To Jonas',
#  'Married To Rock',
#  'Married to Medicine',
#  'Married to Medicine Los Angeles',
#  "Marvel's Avengers: Age of Ultron",
#  'Meet the Press',
#  'Megafault',
#  'Megalodon',
#  'Method of a Serial Killer',
#  'Mexican Dynasties',
#  'Miami Vice',
#  'Michael Jackson & Anna Nicole Smith: Bad Medicine',
#  'Midnight, Texas',
#  'Million Dollar Listing Los Angeles',
#  'Million Dollar Listing NY',
#  'Miz & Mrs',
#  'Morning Joe',
#  'Motive',
#  'Mr. Robot',
#  'Mrs. Eastwood & Company',
#  'Murder and Justice: The Case of Martha Moxley',
#  'Murder for Hire',
#  'NBC News Specials',
#  'NBC Nightly News with Lester Holt',
#  'NCIS',
#  'NCIS: Los Angeles',
#  'Naturally, Danny Seo',
#  'Neverknock',
#  'New Amsterdam',
#  'Night Gallery',
#  'Night of the Living Dead',
#  'Nightflyers',
#  'Nightly News Films',
#  'Nightly Pop',
#  'Nightmare Shark',
#  'Not Set',
#  'Noticias Telemundo',
#  'Noticias Telemundo Mediodía',
#  'Open House NYC',
#  'Outsourced',
#  'Paranormal Witness',
#  'Parks and Recreation',
#  'Path of Destruction',
#  'Pearson',
#  'Pegasus vs. Chimera',
#  'Perfect Harmony',
#  'Piranhaconda',
#  'Power Rangers',
#  'Pretty Wild',
#  'Project Runway',
#  'Psych: The Movie',
#  'Punky Brewster',
#  'Quantum Leap',
#  'Queen of the South',
#  'Real Country',
#  'Red: Werewolf Hunter',
#  'Reign of the Gargoyles',
#  'Relatively Nat & Liv',
#  'Return to Downton Abbey: A Grand Event',
#  'Revenge Body With Khloé Kardashian',
#  'Rob & Chyna',
#  'SYFY WIRE: Con After Dark',
#  'Saturday Night Live',
#  'Saved by the Bell',
#  'Saved by the Bell: The New Class',
#  'Secret Lives of the Super Rich',
#  'Seduced by Evil',
#  'Sex and the City',
#  'Shades of Blue',
#  'Shark Tank',
#  'Shrink',
#  'Siren',
#  'Six Million Dollar Man',
#  'Smash',
#  'Snapped',
#  'So Cosmo',
#  'Solace',
#  'Songland',
#  'Southern Charm',
#  'Southern Charm New Orleans',
#  'Squawk on the Street',
#  'State of Affairs',
#  'Stickman',
#  'Straight Up Steve Austin',
#  'Suelta La Sopa',
#  'Suits',
#  'Summer House',
#  'Sunnyside',
#  'Superstore',
#  'Survivorz',
#  'TODAY',
#  'Tacky House',
#  'Team Ninja Warrior',
#  'Temptation Island',
#  'Texicanas',
#  'That Awkward Moment',
#  'The 11th Hour with Brian Williams',
#  'The Bionic Woman',
#  'The Black Donnellys',
#  'The Blacklist',
#  'The Bling Ring',
#  'The Boy (2015)',
#  'The Brave',
#  'The Cape',
#  'The Champion Within',
#  'The Cromarties',
#  'The Disappearance of Susan Cox Powell',
#  'The Enemy Within',
#  'The Equalizer',
#  'The Event',
#  'The Girl with All the Gifts',
#  'The Good Place',
#  'The Hunger Games',
#  'The Hunger Games: Catching Fire',
#  'The Hunger Games: Mockingjay Part 1',
#  'The Hunger Games: Mockingjay Part 2',
#  'The InBetween',
#  'The Incredible Hulk',
#  'The Kelly Clarkson Show',
#  'The Last Witch Hunter',
#  "The Last Word with Lawrence O'Donnell",
#  'The Magicians',
#  'The Office',
#  'The Paley Center Salutes The Good Place',
#  'The Piketon Family Murders',
#  'The Profit',
#  'The Profit: An Inside Look',
#  'The Rachel Maddow Show',
#  'The Radkes',
#  'The Real Housewives of Atlanta',
#  'The Real Housewives of Beverly Hills',
#  'The Real Housewives of Dallas',
#  'The Real Housewives of New Jersey',
#  'The Real Housewives of New York City',
#  'The Real Housewives of Orange County',
#  'The Real Housewives of Potomac',
#  'The Riveras',
#  'The Secret Life of Kids',
#  'The Susan Cox Powell Story',
#  'The Thing',
#  'The Titan Games',
#  'The Tonight Show Starring Jimmy Fallon',
#  'The Turpin 13: Family Secrets Exposed',
#  'The Village',
#  'The Voice',
#  'The Voice Kids',
#  'The Voyager with Josh Garcia',
#  'The Wall',
#  'This Is Us',
#  'This Is Us ',
#  'Tia & Tamera',
#  'Timeless',
#  'Timothy McVeigh: In Defense Of',
#  'Top Chef',
#  'Top Chef Junior',
#  'Total Divas',
#  'Try My Life',
#  'Uncovered: The Cult of Yahweh Ben Yahweh',
#  'Uncovered: The McMartin Family Trials',
#  'Undercover Boss',
#  'Underworld',
#  'Underworld Awakening',
#  'Underworld: Awakening',
#  'Underworld: Evolution',
#  'Underworld: Rise of the Lycans',
#  'Up All Night',
#  'Up and Vanished',
#  'Valerian',
#  'Valerian and the City of a Thousand Planets',
#  'Van Helsing',
#  'Vanderpump Rules',
#  'Very Cavallari',
#  'Vets Saving Pets',
#  'WAGS LA',
#  'WWE NXT',
#  'WWE Raw',
#  'WWE SmackDown',
#  'Watch What Happens Live',
#  'What Would Ryan Lochte Do?',
#  "What's Cooking With Julie Chrisley",
#  'Whitney',
#  'Will & Grace',
#  'Will & Grace (1998)',
#  'Will & Grace: Original',
#  'World of Dance',
#  'XXX: The Return of Xander Cage',
#  'Xena: Warrior Princess',
#  'Young Hercules',
#  'Zombie Tidal Wave',
#  'xXx: The Return of Xander Cage']

# %%
first(reader)
# Out:
# ('2019W29',
#                                                    key     size     week
#  68  clean/year=2019/week=2019W29/ve_20190721_0008....  2515997  2019W29
#  67  clean/year=2019/week=2019W29/ve_20190721_0007....  7455256  2019W29
#  66  clean/year=2019/week=2019W29/ve_20190721_0006....  7378455  2019W29
#  65  clean/year=2019/week=2019W29/ve_20190721_0005....  7353911  2019W29
#  64  clean/year=2019/week=2019W29/ve_20190721_0004....  7334723  2019W29
#  ..                                                ...      ...      ...
#  4   clean/year=2019/week=2019W29/ve_20190715_0004....  7131500  2019W29
#  3   clean/year=2019/week=2019W29/ve_20190715_0003....  7061960  2019W29
#  2   clean/year=2019/week=2019W29/ve_20190715_0002....  7407983  2019W29
#  1   clean/year=2019/week=2019W29/ve_20190715_0001....  7780944  2019W29
#  0   clean/year=2019/week=2019W29/ve_20190715_0000....  7718716  2019W29
#
#  [69 rows x 3 columns])

# %%
work_d = Path(config['WORK_D'])

# %%
list(work_d.glob('*'))
# Out:
# [PosixPath('/Users/wmcabee/DATA/NBC/work/list_clean_files.csv')]

# %%
df['week'] = df['key'].str.extract(r'/week=(\d+W\d\d)')

# %%
df
# Out:
#                                                    key     size     week
# 0    clean/year=2019/week=2019W29/ve_20190715_0000....  7718716  2019W29
# 1    clean/year=2019/week=2019W29/ve_20190715_0001....  7780944  2019W29
# 2    clean/year=2019/week=2019W29/ve_20190715_0002....  7407983  2019W29
# 3    clean/year=2019/week=2019W29/ve_20190715_0003....  7061960  2019W29
# 4    clean/year=2019/week=2019W29/ve_20190715_0004....  7131500  2019W29
# ..                                                 ...      ...      ...
# 809  clean/year=2019/week=2019W40/ve_20191001_0000....  8080038  2019W40
# 810  clean/year=2019/week=2019W40/ve_20191001_0001....  8193853  2019W40
# 811  clean/year=2019/week=2019W40/ve_20191001_0002....  8093150  2019W40
# 812  clean/year=2019/week=2019W40/ve_20191001_0003....  8144759  2019W40
# 813  clean/year=2019/week=2019W40/ve_20191001_0004....  4109810  2019W40
#
# [814 rows x 3 columns]
