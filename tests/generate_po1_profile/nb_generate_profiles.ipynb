# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from test_generate_profiles import test_generate_profiles, _get_config
from nbc_analysis.utils.debug_utils import runit
import pandas as pd

from toolz import *
import re
from pathlib import Path

# %%
config = _get_config()
# Out:
# 2019-10-12 22:14:26,405|WARNING|nbc_analysis.utils.config_utils|The 'default' config is intended for testing only. For production, use /Users/wmcabee/.config/nbc_analysis/config.yaml

# %%
df = runit(test_generate_profiles)
# Out:
# 2019-10-12 22:41:35,758|WARNING|nbc_analysis.utils.config_utils|The 'default' config is intended for testing only. For production, use /Users/wmcabee/.config/nbc_analysis/config.yaml
# 2019-10-12 22:41:35,761|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,bucket_key=nbc-partitions-video-end
# 2019-10-12 22:41:35,772|INFO|nbc_analysis.generate_po1_profiles.main|start initialize_gen_profiles
# 2019-10-12 22:41:35,775|INFO|nbc_analysis.generate_po1_profiles.main|start list_clean_files
# 2019-10-12 22:41:36,518|INFO|nbc_analysis.generate_po1_profiles.main|end list_clean_files
# 2019-10-12 22:41:36,525|INFO|nbc_analysis.generate_po1_profiles.main|wrote /Users/wmcabee/DATA/NBC/work/list_clean_files.csv,records=814
# 2019-10-12 22:41:36,525|INFO|nbc_analysis.generate_po1_profiles.main|end initialize_gen_profiles
# 2019-10-12 22:41:36,535|INFO|nbc_analysis.generate_po1_profiles.main|start proc_week,week_id=2019W39,records=106
# 2019-10-12 22:41:36,537|WARNING|nbc_analysis.utils.func_utils|MERGE_LIMIT set,limit=2
# 2019-10-12 22:41:36,538|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W39/ve_20190923_0000.parquet,outfile=ve_20190923_0000.parquet
# 2019-10-12 22:41:37,424|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W39/ve_20190923_0000.parquet
# 2019-10-12 22:41:37,425|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W39/ve_20190923_0001.parquet,outfile=ve_20190923_0001.parquet
# 2019-10-12 22:41:38,010|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W39/ve_20190923_0001.parquet
# 2019-10-12 22:41:38,289|INFO|nbc_analysis.generate_po1_profiles.main|start file,file=ve_20190923_0000.parquet,records=100828,1/2
# 2019-10-12 22:41:38,290|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,file_name=ve_20190923_0000.parquet, in_records=100828
# 2019-10-12 22:41:38,328|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 22:41:38,329|INFO|nbc_analysis.generate_po1_profiles.main|week_id=2019W39,file_name=ve_20190923_0000.parquet,record=0,records_in_file=100828,pct=0.0%
# 2019-10-12 22:41:39,229|INFO|nbc_analysis.generate_po1_profiles.main|deleting file,file=ve_20190923_0000.parquet
# 2019-10-12 22:41:39,432|INFO|nbc_analysis.generate_po1_profiles.main|start file,file=ve_20190923_0001.parquet,records=100704,2/2
# 2019-10-12 22:41:39,447|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,file_name=ve_20190923_0001.parquet, in_records=100704
# 2019-10-12 22:41:39,474|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 22:41:39,475|INFO|nbc_analysis.generate_po1_profiles.main|week_id=2019W39,file_name=ve_20190923_0001.parquet,record=0,records_in_file=100704,pct=0.0%
# 2019-10-12 22:41:40,148|INFO|nbc_analysis.generate_po1_profiles.main|deleting file,file=ve_20190923_0001.parquet
# 2019-10-12 22:41:40,170|INFO|nbc_analysis.generate_po1_profiles.main|wrote file=/Users/wmcabee/DATA/NBC/work/2019W39/nbc_profile_2019W39.json.gz
# 2019-10-12 22:41:40,171|INFO|nbc_analysis.generate_po1_profiles.main|start upload_profile,key=nbc_profiles/nbc_profile_2019W39.json.gz
# 2019-10-12 22:41:41,124|INFO|nbc_analysis.generate_po1_profiles.main|deleting profile file,infile=/Users/wmcabee/DATA/NBC/work/2019W39/nbc_profile_2019W39.json.gz
# 2019-10-12 22:41:41,125|INFO|nbc_analysis.generate_po1_profiles.main|end upload_profile,key=nbc_profiles/nbc_profile_2019W39.json.gz
# 2019-10-12 22:41:41,126|INFO|nbc_analysis.generate_po1_profiles.main|end proc_week,week_id=2019W39
# 2019-10-12 22:41:41,127|INFO|nbc_analysis.generate_po1_profiles.main|start proc_week,week_id=2019W38,records=73
# 2019-10-12 22:41:41,128|WARNING|nbc_analysis.utils.func_utils|MERGE_LIMIT set,limit=2
# 2019-10-12 22:41:41,129|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W38/ve_20190916_0000.parquet,outfile=ve_20190916_0000.parquet
# 2019-10-12 22:41:41,701|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W38/ve_20190916_0000.parquet
# 2019-10-12 22:41:41,702|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W38/ve_20190916_0001.parquet,outfile=ve_20190916_0001.parquet
# 2019-10-12 22:41:42,269|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W38/ve_20190916_0001.parquet
# 2019-10-12 22:41:42,423|INFO|nbc_analysis.generate_po1_profiles.main|start file,file=ve_20190916_0000.parquet,records=100120,1/2
# 2019-10-12 22:41:42,424|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,file_name=ve_20190916_0000.parquet, in_records=100120
# 2019-10-12 22:41:42,448|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 22:41:42,449|INFO|nbc_analysis.generate_po1_profiles.main|week_id=2019W38,file_name=ve_20190916_0000.parquet,record=0,records_in_file=100120,pct=0.0%
# 2019-10-12 22:41:43,120|INFO|nbc_analysis.generate_po1_profiles.main|deleting file,file=ve_20190916_0000.parquet
# 2019-10-12 22:41:43,290|INFO|nbc_analysis.generate_po1_profiles.main|start file,file=ve_20190916_0001.parquet,records=100248,2/2
# 2019-10-12 22:41:43,303|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,file_name=ve_20190916_0001.parquet, in_records=100248
# 2019-10-12 22:41:43,326|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 22:41:43,327|INFO|nbc_analysis.generate_po1_profiles.main|week_id=2019W38,file_name=ve_20190916_0001.parquet,record=0,records_in_file=100248,pct=0.0%
# 2019-10-12 22:41:43,991|INFO|nbc_analysis.generate_po1_profiles.main|deleting file,file=ve_20190916_0001.parquet
# 2019-10-12 22:41:44,011|INFO|nbc_analysis.generate_po1_profiles.main|wrote file=/Users/wmcabee/DATA/NBC/work/2019W38/nbc_profile_2019W38.json.gz
# 2019-10-12 22:41:44,013|INFO|nbc_analysis.generate_po1_profiles.main|start upload_profile,key=nbc_profiles/nbc_profile_2019W38.json.gz
# 2019-10-12 22:41:44,366|INFO|nbc_analysis.generate_po1_profiles.main|deleting profile file,infile=/Users/wmcabee/DATA/NBC/work/2019W38/nbc_profile_2019W38.json.gz
# 2019-10-12 22:41:44,367|INFO|nbc_analysis.generate_po1_profiles.main|end upload_profile,key=nbc_profiles/nbc_profile_2019W38.json.gz
# 2019-10-12 22:41:44,368|INFO|nbc_analysis.generate_po1_profiles.main|end proc_week,week_id=2019W38
# 2019-10-12 22:41:44,369|INFO|nbc_analysis.generate_po1_profiles.main|start proc_week,week_id=2019W37,records=70
# 2019-10-12 22:41:44,370|WARNING|nbc_analysis.utils.func_utils|MERGE_LIMIT set,limit=2
# 2019-10-12 22:41:44,371|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W37/ve_20190909_0000.parquet,outfile=ve_20190909_0000.parquet
# 2019-10-12 22:41:44,896|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W37/ve_20190909_0000.parquet
# 2019-10-12 22:41:44,897|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W37/ve_20190909_0001.parquet,outfile=ve_20190909_0001.parquet
# 2019-10-12 22:41:45,443|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W37/ve_20190909_0001.parquet
# 2019-10-12 22:41:45,601|INFO|nbc_analysis.generate_po1_profiles.main|start file,file=ve_20190909_0001.parquet,records=100034,1/2
# 2019-10-12 22:41:45,601|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,file_name=ve_20190909_0001.parquet, in_records=100034
# 2019-10-12 22:41:45,623|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 22:41:45,624|INFO|nbc_analysis.generate_po1_profiles.main|week_id=2019W37,file_name=ve_20190909_0001.parquet,record=0,records_in_file=100034,pct=0.0%
# 2019-10-12 22:41:46,309|INFO|nbc_analysis.generate_po1_profiles.main|deleting file,file=ve_20190909_0001.parquet
# 2019-10-12 22:41:46,481|INFO|nbc_analysis.generate_po1_profiles.main|start file,file=ve_20190909_0000.parquet,records=101062,2/2
# 2019-10-12 22:41:46,494|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,file_name=ve_20190909_0000.parquet, in_records=101062
# 2019-10-12 22:41:46,517|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 22:41:46,517|INFO|nbc_analysis.generate_po1_profiles.main|week_id=2019W37,file_name=ve_20190909_0000.parquet,record=0,records_in_file=101062,pct=0.0%
# 2019-10-12 22:41:47,197|INFO|nbc_analysis.generate_po1_profiles.main|deleting file,file=ve_20190909_0000.parquet
# 2019-10-12 22:41:47,218|INFO|nbc_analysis.generate_po1_profiles.main|wrote file=/Users/wmcabee/DATA/NBC/work/2019W37/nbc_profile_2019W37.json.gz
# 2019-10-12 22:41:47,219|INFO|nbc_analysis.generate_po1_profiles.main|start upload_profile,key=nbc_profiles/nbc_profile_2019W37.json.gz
# 2019-10-12 22:41:47,522|INFO|nbc_analysis.generate_po1_profiles.main|deleting profile file,infile=/Users/wmcabee/DATA/NBC/work/2019W37/nbc_profile_2019W37.json.gz
# 2019-10-12 22:41:47,523|INFO|nbc_analysis.generate_po1_profiles.main|end upload_profile,key=nbc_profiles/nbc_profile_2019W37.json.gz
# 2019-10-12 22:41:47,524|INFO|nbc_analysis.generate_po1_profiles.main|end proc_week,week_id=2019W37
# 2019-10-12 22:41:47,525|INFO|nbc_analysis.generate_po1_profiles.main|start proc_week,week_id=2019W36,records=68
# 2019-10-12 22:41:47,526|WARNING|nbc_analysis.utils.func_utils|MERGE_LIMIT set,limit=2
# 2019-10-12 22:41:47,527|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W36/ve_20190902_0000.parquet,outfile=ve_20190902_0000.parquet
# 2019-10-12 22:41:48,075|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W36/ve_20190902_0000.parquet
# 2019-10-12 22:41:48,076|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W36/ve_20190902_0001.parquet,outfile=ve_20190902_0001.parquet
# 2019-10-12 22:41:48,591|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W36/ve_20190902_0001.parquet
# 2019-10-12 22:41:48,752|INFO|nbc_analysis.generate_po1_profiles.main|start file,file=ve_20190902_0001.parquet,records=100709,1/2
# 2019-10-12 22:41:48,753|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,file_name=ve_20190902_0001.parquet, in_records=100709
# 2019-10-12 22:41:48,774|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 22:41:48,774|INFO|nbc_analysis.generate_po1_profiles.main|week_id=2019W36,file_name=ve_20190902_0001.parquet,record=0,records_in_file=100709,pct=0.0%
# 2019-10-12 22:41:49,446|INFO|nbc_analysis.generate_po1_profiles.main|deleting file,file=ve_20190902_0001.parquet
# 2019-10-12 22:41:49,631|INFO|nbc_analysis.generate_po1_profiles.main|start file,file=ve_20190902_0000.parquet,records=101955,2/2
# 2019-10-12 22:41:49,642|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,file_name=ve_20190902_0000.parquet, in_records=101955
# 2019-10-12 22:41:49,663|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 22:41:49,664|INFO|nbc_analysis.generate_po1_profiles.main|week_id=2019W36,file_name=ve_20190902_0000.parquet,record=0,records_in_file=101955,pct=0.0%
# 2019-10-12 22:41:50,355|INFO|nbc_analysis.generate_po1_profiles.main|deleting file,file=ve_20190902_0000.parquet
# 2019-10-12 22:41:50,375|INFO|nbc_analysis.generate_po1_profiles.main|wrote file=/Users/wmcabee/DATA/NBC/work/2019W36/nbc_profile_2019W36.json.gz
# 2019-10-12 22:41:50,376|INFO|nbc_analysis.generate_po1_profiles.main|start upload_profile,key=nbc_profiles/nbc_profile_2019W36.json.gz
# 2019-10-12 22:41:50,663|INFO|nbc_analysis.generate_po1_profiles.main|deleting profile file,infile=/Users/wmcabee/DATA/NBC/work/2019W36/nbc_profile_2019W36.json.gz
# 2019-10-12 22:41:50,665|INFO|nbc_analysis.generate_po1_profiles.main|end upload_profile,key=nbc_profiles/nbc_profile_2019W36.json.gz
# 2019-10-12 22:41:50,666|INFO|nbc_analysis.generate_po1_profiles.main|end proc_week,week_id=2019W36
# 2019-10-12 22:41:50,666|INFO|nbc_analysis.generate_po1_profiles.main|start proc_week,week_id=2019W35,records=67
# 2019-10-12 22:41:50,668|WARNING|nbc_analysis.utils.func_utils|MERGE_LIMIT set,limit=2
# 2019-10-12 22:41:50,669|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W35/ve_20190826_0000.parquet,outfile=ve_20190826_0000.parquet
# 2019-10-12 22:41:51,226|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W35/ve_20190826_0000.parquet
# 2019-10-12 22:41:51,226|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W35/ve_20190826_0001.parquet,outfile=ve_20190826_0001.parquet
# 2019-10-12 22:41:51,765|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W35/ve_20190826_0001.parquet
# 2019-10-12 22:41:51,947|INFO|nbc_analysis.generate_po1_profiles.main|start file,file=ve_20190826_0000.parquet,records=100080,1/2
# 2019-10-12 22:41:51,947|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,file_name=ve_20190826_0000.parquet, in_records=100080
# 2019-10-12 22:41:51,975|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 22:41:51,976|INFO|nbc_analysis.generate_po1_profiles.main|week_id=2019W35,file_name=ve_20190826_0000.parquet,record=0,records_in_file=100080,pct=0.0%
# 2019-10-12 22:41:52,652|INFO|nbc_analysis.generate_po1_profiles.main|deleting file,file=ve_20190826_0000.parquet
# 2019-10-12 22:41:52,848|INFO|nbc_analysis.generate_po1_profiles.main|start file,file=ve_20190826_0001.parquet,records=99970,2/2
# 2019-10-12 22:41:52,862|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,file_name=ve_20190826_0001.parquet, in_records=99970
# 2019-10-12 22:41:52,888|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 22:41:52,889|INFO|nbc_analysis.generate_po1_profiles.main|week_id=2019W35,file_name=ve_20190826_0001.parquet,record=0,records_in_file=99970,pct=0.0%
# 2019-10-12 22:41:53,576|INFO|nbc_analysis.generate_po1_profiles.main|deleting file,file=ve_20190826_0001.parquet
# 2019-10-12 22:41:53,593|INFO|nbc_analysis.generate_po1_profiles.main|wrote file=/Users/wmcabee/DATA/NBC/work/2019W35/nbc_profile_2019W35.json.gz
# 2019-10-12 22:41:53,594|INFO|nbc_analysis.generate_po1_profiles.main|start upload_profile,key=nbc_profiles/nbc_profile_2019W35.json.gz
# 2019-10-12 22:41:53,891|INFO|nbc_analysis.generate_po1_profiles.main|deleting profile file,infile=/Users/wmcabee/DATA/NBC/work/2019W35/nbc_profile_2019W35.json.gz
# 2019-10-12 22:41:53,892|INFO|nbc_analysis.generate_po1_profiles.main|end upload_profile,key=nbc_profiles/nbc_profile_2019W35.json.gz
# 2019-10-12 22:41:53,893|INFO|nbc_analysis.generate_po1_profiles.main|end proc_week,week_id=2019W35
# 2019-10-12 22:41:53,894|INFO|nbc_analysis.generate_po1_profiles.main|start proc_week,week_id=2019W34,records=68
# 2019-10-12 22:41:53,896|WARNING|nbc_analysis.utils.func_utils|MERGE_LIMIT set,limit=2
# 2019-10-12 22:41:53,896|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W34/ve_20190819_0000.parquet,outfile=ve_20190819_0000.parquet
# 2019-10-12 22:41:54,421|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W34/ve_20190819_0000.parquet
# 2019-10-12 22:41:54,422|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W34/ve_20190819_0001.parquet,outfile=ve_20190819_0001.parquet
# 2019-10-12 22:41:54,955|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W34/ve_20190819_0001.parquet
# 2019-10-12 22:41:55,142|INFO|nbc_analysis.generate_po1_profiles.main|start file,file=ve_20190819_0001.parquet,records=99646,1/2
# 2019-10-12 22:41:55,143|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,file_name=ve_20190819_0001.parquet, in_records=99646
# 2019-10-12 22:41:55,170|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 22:41:55,170|INFO|nbc_analysis.generate_po1_profiles.main|week_id=2019W34,file_name=ve_20190819_0001.parquet,record=0,records_in_file=99646,pct=0.0%
# 2019-10-12 22:41:55,844|INFO|nbc_analysis.generate_po1_profiles.main|deleting file,file=ve_20190819_0001.parquet
# 2019-10-12 22:41:56,030|INFO|nbc_analysis.generate_po1_profiles.main|start file,file=ve_20190819_0000.parquet,records=99527,2/2
# 2019-10-12 22:41:56,044|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,file_name=ve_20190819_0000.parquet, in_records=99527
# 2019-10-12 22:41:56,070|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 22:41:56,071|INFO|nbc_analysis.generate_po1_profiles.main|week_id=2019W34,file_name=ve_20190819_0000.parquet,record=0,records_in_file=99527,pct=0.0%
# 2019-10-12 22:41:56,801|INFO|nbc_analysis.generate_po1_profiles.main|deleting file,file=ve_20190819_0000.parquet
# 2019-10-12 22:41:56,822|INFO|nbc_analysis.generate_po1_profiles.main|wrote file=/Users/wmcabee/DATA/NBC/work/2019W34/nbc_profile_2019W34.json.gz
# 2019-10-12 22:41:56,823|INFO|nbc_analysis.generate_po1_profiles.main|start upload_profile,key=nbc_profiles/nbc_profile_2019W34.json.gz
# 2019-10-12 22:41:57,365|INFO|nbc_analysis.generate_po1_profiles.main|deleting profile file,infile=/Users/wmcabee/DATA/NBC/work/2019W34/nbc_profile_2019W34.json.gz
# 2019-10-12 22:41:57,366|INFO|nbc_analysis.generate_po1_profiles.main|end upload_profile,key=nbc_profiles/nbc_profile_2019W34.json.gz
# 2019-10-12 22:41:57,367|INFO|nbc_analysis.generate_po1_profiles.main|end proc_week,week_id=2019W34
# 2019-10-12 22:41:57,368|INFO|nbc_analysis.generate_po1_profiles.main|start proc_week,week_id=2019W33,records=70
# 2019-10-12 22:41:57,369|WARNING|nbc_analysis.utils.func_utils|MERGE_LIMIT set,limit=2
# 2019-10-12 22:41:57,370|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W33/ve_20190812_0000.parquet,outfile=ve_20190812_0000.parquet
# 2019-10-12 22:41:57,927|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W33/ve_20190812_0000.parquet
# 2019-10-12 22:41:57,928|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W33/ve_20190812_0001.parquet,outfile=ve_20190812_0001.parquet
# 2019-10-12 22:41:58,487|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W33/ve_20190812_0001.parquet
# 2019-10-12 22:41:58,642|INFO|nbc_analysis.generate_po1_profiles.main|start file,file=ve_20190812_0001.parquet,records=98876,1/2
# 2019-10-12 22:41:58,643|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,file_name=ve_20190812_0001.parquet, in_records=98876
# 2019-10-12 22:41:58,664|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 22:41:58,665|INFO|nbc_analysis.generate_po1_profiles.main|week_id=2019W33,file_name=ve_20190812_0001.parquet,record=0,records_in_file=98876,pct=0.0%
# 2019-10-12 22:41:59,325|INFO|nbc_analysis.generate_po1_profiles.main|deleting file,file=ve_20190812_0001.parquet
# 2019-10-12 22:41:59,489|INFO|nbc_analysis.generate_po1_profiles.main|start file,file=ve_20190812_0000.parquet,records=99463,2/2
# 2019-10-12 22:41:59,501|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,file_name=ve_20190812_0000.parquet, in_records=99463
# 2019-10-12 22:41:59,523|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 22:41:59,524|INFO|nbc_analysis.generate_po1_profiles.main|week_id=2019W33,file_name=ve_20190812_0000.parquet,record=0,records_in_file=99463,pct=0.0%
# 2019-10-12 22:42:00,195|INFO|nbc_analysis.generate_po1_profiles.main|deleting file,file=ve_20190812_0000.parquet
# 2019-10-12 22:42:00,217|INFO|nbc_analysis.generate_po1_profiles.main|wrote file=/Users/wmcabee/DATA/NBC/work/2019W33/nbc_profile_2019W33.json.gz
# 2019-10-12 22:42:00,218|INFO|nbc_analysis.generate_po1_profiles.main|start upload_profile,key=nbc_profiles/nbc_profile_2019W33.json.gz
# 2019-10-12 22:42:00,637|INFO|nbc_analysis.generate_po1_profiles.main|deleting profile file,infile=/Users/wmcabee/DATA/NBC/work/2019W33/nbc_profile_2019W33.json.gz
# 2019-10-12 22:42:00,639|INFO|nbc_analysis.generate_po1_profiles.main|end upload_profile,key=nbc_profiles/nbc_profile_2019W33.json.gz
# 2019-10-12 22:42:00,639|INFO|nbc_analysis.generate_po1_profiles.main|end proc_week,week_id=2019W33
# 2019-10-12 22:42:00,641|INFO|nbc_analysis.generate_po1_profiles.main|start proc_week,week_id=2019W32,records=66
# 2019-10-12 22:42:00,642|WARNING|nbc_analysis.utils.func_utils|MERGE_LIMIT set,limit=2
# 2019-10-12 22:42:00,643|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W32/ve_20190805_0000.parquet,outfile=ve_20190805_0000.parquet
# 2019-10-12 22:42:01,189|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W32/ve_20190805_0000.parquet
# 2019-10-12 22:42:01,190|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W32/ve_20190805_0001.parquet,outfile=ve_20190805_0001.parquet
# 2019-10-12 22:42:01,733|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W32/ve_20190805_0001.parquet
# 2019-10-12 22:42:01,887|INFO|nbc_analysis.generate_po1_profiles.main|start file,file=ve_20190805_0000.parquet,records=99245,1/2
# 2019-10-12 22:42:01,888|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,file_name=ve_20190805_0000.parquet, in_records=99245
# 2019-10-12 22:42:01,909|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 22:42:01,910|INFO|nbc_analysis.generate_po1_profiles.main|week_id=2019W32,file_name=ve_20190805_0000.parquet,record=0,records_in_file=99245,pct=0.0%
# 2019-10-12 22:42:02,582|INFO|nbc_analysis.generate_po1_profiles.main|deleting file,file=ve_20190805_0000.parquet
# 2019-10-12 22:42:02,745|INFO|nbc_analysis.generate_po1_profiles.main|start file,file=ve_20190805_0001.parquet,records=98841,2/2
# 2019-10-12 22:42:02,758|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,file_name=ve_20190805_0001.parquet, in_records=98841
# 2019-10-12 22:42:02,780|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 22:42:02,781|INFO|nbc_analysis.generate_po1_profiles.main|week_id=2019W32,file_name=ve_20190805_0001.parquet,record=0,records_in_file=98841,pct=0.0%
# 2019-10-12 22:42:03,444|INFO|nbc_analysis.generate_po1_profiles.main|deleting file,file=ve_20190805_0001.parquet
# 2019-10-12 22:42:03,461|INFO|nbc_analysis.generate_po1_profiles.main|wrote file=/Users/wmcabee/DATA/NBC/work/2019W32/nbc_profile_2019W32.json.gz
# 2019-10-12 22:42:03,461|INFO|nbc_analysis.generate_po1_profiles.main|start upload_profile,key=nbc_profiles/nbc_profile_2019W32.json.gz
# 2019-10-12 22:42:03,775|INFO|nbc_analysis.generate_po1_profiles.main|deleting profile file,infile=/Users/wmcabee/DATA/NBC/work/2019W32/nbc_profile_2019W32.json.gz
# 2019-10-12 22:42:03,776|INFO|nbc_analysis.generate_po1_profiles.main|end upload_profile,key=nbc_profiles/nbc_profile_2019W32.json.gz
# 2019-10-12 22:42:03,777|INFO|nbc_analysis.generate_po1_profiles.main|end proc_week,week_id=2019W32
# 2019-10-12 22:42:03,777|INFO|nbc_analysis.generate_po1_profiles.main|start proc_week,week_id=2019W31,records=67
# 2019-10-12 22:42:03,779|WARNING|nbc_analysis.utils.func_utils|MERGE_LIMIT set,limit=2
# 2019-10-12 22:42:03,780|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W31/ve_20190729_0000.parquet,outfile=ve_20190729_0000.parquet
# 2019-10-12 22:42:04,336|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W31/ve_20190729_0000.parquet
# 2019-10-12 22:42:04,337|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W31/ve_20190729_0001.parquet,outfile=ve_20190729_0001.parquet
# 2019-10-12 22:42:04,930|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W31/ve_20190729_0001.parquet
# 2019-10-12 22:42:05,127|INFO|nbc_analysis.generate_po1_profiles.main|start file,file=ve_20190729_0000.parquet,records=99459,1/2
# 2019-10-12 22:42:05,128|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,file_name=ve_20190729_0000.parquet, in_records=99459
# 2019-10-12 22:42:05,154|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 22:42:05,155|INFO|nbc_analysis.generate_po1_profiles.main|week_id=2019W31,file_name=ve_20190729_0000.parquet,record=0,records_in_file=99459,pct=0.0%
# 2019-10-12 22:42:05,845|INFO|nbc_analysis.generate_po1_profiles.main|deleting file,file=ve_20190729_0000.parquet
# 2019-10-12 22:42:06,037|INFO|nbc_analysis.generate_po1_profiles.main|start file,file=ve_20190729_0001.parquet,records=99421,2/2
# 2019-10-12 22:42:06,050|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,file_name=ve_20190729_0001.parquet, in_records=99421
# 2019-10-12 22:42:06,076|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 22:42:06,077|INFO|nbc_analysis.generate_po1_profiles.main|week_id=2019W31,file_name=ve_20190729_0001.parquet,record=0,records_in_file=99421,pct=0.0%
# 2019-10-12 22:42:06,747|INFO|nbc_analysis.generate_po1_profiles.main|deleting file,file=ve_20190729_0001.parquet
# 2019-10-12 22:42:06,768|INFO|nbc_analysis.generate_po1_profiles.main|wrote file=/Users/wmcabee/DATA/NBC/work/2019W31/nbc_profile_2019W31.json.gz
# 2019-10-12 22:42:06,769|INFO|nbc_analysis.generate_po1_profiles.main|start upload_profile,key=nbc_profiles/nbc_profile_2019W31.json.gz
# 2019-10-12 22:42:07,160|INFO|nbc_analysis.generate_po1_profiles.main|deleting profile file,infile=/Users/wmcabee/DATA/NBC/work/2019W31/nbc_profile_2019W31.json.gz
# 2019-10-12 22:42:07,162|INFO|nbc_analysis.generate_po1_profiles.main|end upload_profile,key=nbc_profiles/nbc_profile_2019W31.json.gz
# 2019-10-12 22:42:07,163|INFO|nbc_analysis.generate_po1_profiles.main|end proc_week,week_id=2019W31
# 2019-10-12 22:42:07,164|INFO|nbc_analysis.generate_po1_profiles.main|start proc_week,week_id=2019W30,records=71
# 2019-10-12 22:42:07,165|WARNING|nbc_analysis.utils.func_utils|MERGE_LIMIT set,limit=2
# 2019-10-12 22:42:07,166|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W30/ve_20190722_0000.parquet,outfile=ve_20190722_0000.parquet
# 2019-10-12 22:42:07,711|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W30/ve_20190722_0000.parquet
# 2019-10-12 22:42:07,712|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W30/ve_20190722_0001.parquet,outfile=ve_20190722_0001.parquet
# 2019-10-12 22:42:08,282|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W30/ve_20190722_0001.parquet
# 2019-10-12 22:42:08,441|INFO|nbc_analysis.generate_po1_profiles.main|start file,file=ve_20190722_0000.parquet,records=100336,1/2
# 2019-10-12 22:42:08,442|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,file_name=ve_20190722_0000.parquet, in_records=100336
# 2019-10-12 22:42:08,464|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 22:42:08,465|INFO|nbc_analysis.generate_po1_profiles.main|week_id=2019W30,file_name=ve_20190722_0000.parquet,record=0,records_in_file=100336,pct=0.0%
# 2019-10-12 22:42:09,125|INFO|nbc_analysis.generate_po1_profiles.main|deleting file,file=ve_20190722_0000.parquet
# 2019-10-12 22:42:09,291|INFO|nbc_analysis.generate_po1_profiles.main|start file,file=ve_20190722_0001.parquet,records=99805,2/2
# 2019-10-12 22:42:09,303|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,file_name=ve_20190722_0001.parquet, in_records=99805
# 2019-10-12 22:42:09,325|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 22:42:09,326|INFO|nbc_analysis.generate_po1_profiles.main|week_id=2019W30,file_name=ve_20190722_0001.parquet,record=0,records_in_file=99805,pct=0.0%
# 2019-10-12 22:42:10,023|INFO|nbc_analysis.generate_po1_profiles.main|deleting file,file=ve_20190722_0001.parquet
# 2019-10-12 22:42:10,041|INFO|nbc_analysis.generate_po1_profiles.main|wrote file=/Users/wmcabee/DATA/NBC/work/2019W30/nbc_profile_2019W30.json.gz
# 2019-10-12 22:42:10,042|INFO|nbc_analysis.generate_po1_profiles.main|start upload_profile,key=nbc_profiles/nbc_profile_2019W30.json.gz
# 2019-10-12 22:42:10,353|INFO|nbc_analysis.generate_po1_profiles.main|deleting profile file,infile=/Users/wmcabee/DATA/NBC/work/2019W30/nbc_profile_2019W30.json.gz
# 2019-10-12 22:42:10,355|INFO|nbc_analysis.generate_po1_profiles.main|end upload_profile,key=nbc_profiles/nbc_profile_2019W30.json.gz
# 2019-10-12 22:42:10,356|INFO|nbc_analysis.generate_po1_profiles.main|end proc_week,week_id=2019W30
# 2019-10-12 22:42:10,357|INFO|nbc_analysis.generate_po1_profiles.main|start proc_week,week_id=2019W29,records=69
# 2019-10-12 22:42:10,358|WARNING|nbc_analysis.utils.func_utils|MERGE_LIMIT set,limit=2
# 2019-10-12 22:42:10,359|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W29/ve_20190715_0000.parquet,outfile=ve_20190715_0000.parquet
# 2019-10-12 22:42:10,898|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W29/ve_20190715_0000.parquet
# 2019-10-12 22:42:10,899|INFO|nbc_analysis.generate_po1_profiles.main|start download_clean_file,key=clean/year=2019/week=2019W29/ve_20190715_0001.parquet,outfile=ve_20190715_0001.parquet
# 2019-10-12 22:42:11,476|INFO|nbc_analysis.generate_po1_profiles.main|end download_clean_file,key=clean/year=2019/week=2019W29/ve_20190715_0001.parquet
# 2019-10-12 22:42:11,696|INFO|nbc_analysis.generate_po1_profiles.main|start file,file=ve_20190715_0001.parquet,records=99865,1/2
# 2019-10-12 22:42:11,696|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,file_name=ve_20190715_0001.parquet, in_records=99865
# 2019-10-12 22:42:11,722|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 22:42:11,723|INFO|nbc_analysis.generate_po1_profiles.main|week_id=2019W29,file_name=ve_20190715_0001.parquet,record=0,records_in_file=99865,pct=0.0%
# 2019-10-12 22:42:12,413|INFO|nbc_analysis.generate_po1_profiles.main|deleting file,file=ve_20190715_0001.parquet
# 2019-10-12 22:42:12,613|INFO|nbc_analysis.generate_po1_profiles.main|start file,file=ve_20190715_0000.parquet,records=100073,2/2
# 2019-10-12 22:42:12,628|INFO|nbc_analysis.generate_po1_profiles.main|start gen_profiles,file_name=ve_20190715_0000.parquet, in_records=100073
# 2019-10-12 22:42:12,653|WARNING|nbc_analysis.utils.func_utils|PROFILE_PER_WEEK_LIMIT set,limit=1000
# 2019-10-12 22:42:12,654|INFO|nbc_analysis.generate_po1_profiles.main|week_id=2019W29,file_name=ve_20190715_0000.parquet,record=0,records_in_file=100073,pct=0.0%
# 2019-10-12 22:42:13,375|INFO|nbc_analysis.generate_po1_profiles.main|deleting file,file=ve_20190715_0000.parquet
# 2019-10-12 22:42:13,393|INFO|nbc_analysis.generate_po1_profiles.main|wrote file=/Users/wmcabee/DATA/NBC/work/2019W29/nbc_profile_2019W29.json.gz
# 2019-10-12 22:42:13,393|INFO|nbc_analysis.generate_po1_profiles.main|start upload_profile,key=nbc_profiles/nbc_profile_2019W29.json.gz
# 2019-10-12 22:42:13,668|INFO|nbc_analysis.generate_po1_profiles.main|deleting profile file,infile=/Users/wmcabee/DATA/NBC/work/2019W29/nbc_profile_2019W29.json.gz
# 2019-10-12 22:42:13,669|INFO|nbc_analysis.generate_po1_profiles.main|end upload_profile,key=nbc_profiles/nbc_profile_2019W29.json.gz
# 2019-10-12 22:42:13,670|INFO|nbc_analysis.generate_po1_profiles.main|end proc_week,week_id=2019W29
# 2019-10-12 22:42:13,671|INFO|nbc_analysis.generate_po1_profiles.main|end gen_profiles

# %%
df
# Out:
# ['#1 Single',
#  '#RichKids of Beverly Hills',
#  '1st Look',
#  '2 Lava 2 Lantula',
#  '30 Rock',
#  '47 Ronin',
#  '5-Headed Shark Attack',
#  '6-Headed Shark Attack',
#  'A Lie to Die For',
#  'A Little Late with Lilly Singh',
#  'A Madea Christmas',
#  'A Very Wicked Halloween: Celebrating 15 Years on Broadway',
#  'A Wedding and a Murder',
#  'A-List Listings',
#  'A.P. Bio',
#  'AM Joy',
#  'Aaron Hernandez Uncovered',
#  'Aaron Hernandez, McNair & Dele: Dangerous Games',
#  "Abby's",
#  'Access',
#  'Access Hollywood',
#  'After Lately',
#  'Al Rojo Vivo',
#  'Aladdin and the Death Lamp',
#  'Alien News Desk',
#  'Alien Siege',
#  'All In with Chris Hayes',
#  'Allegiance',
#  'Amazing Stories',
#  "America's Got Talent",
#  'American Greed',
#  'American Greed: Deadly Rich',
#  'American Horror House',
#  'American Ninja Warrior',
#  'American Ninja Warrior Junior',
#  'American Ninja Warrior: Ninja vs Ninja',
#  'American Swamp',
#  'Ant-Man',
#  'Arctic Predator',
#  'Ashlee+Evan',
#  'Atomica',
#  'Average Joe',
#  'Battle at Big Rock',
#  'Battlestar Galactica',
#  'Battlestar Galactica (1978)',
#  'Battlestar Galactica: The Mini-Series',
#  'Below Deck',
#  'Below Deck Mediterranean',
#  'Best Room Wins',
#  'Better Late Than Never',
#  'Beverly Hills Dog Show',
#  'Big Rich Atlanta',
#  'Big Rich Texas',
#  'Big Star Little Star',
#  'Billboard Music Awards',
#  'Blindspot',
#  'Blood Drive',
#  'Bluff City Law',
#  'Bobbi Kristina Brown: Deadly Legacy',
#  'Bobby & Iza',
#  'Boo! A Madea Halloween',
#  'Botched',
#  'Botched By Nature',
#  "Brian's Song",
#  'Bridalplasty',
#  'Bring the Funny',
#  'Brooklyn Nine-Nine',
#  'Buck Rogers in the 25th Century',
#  'Buried in the Backyard',
#  'CSI',
#  'Camera Obscura',
#  'Cash Pad',
#  'Catching Kelce',
#  'Channel Zero: The Dream Door',
#  'Charles in Charge',
#  'Chicago Fire',
#  'Chicago Med',
#  'Chicago P.D.',
#  'Chrisley Knows Best',
#  'Christina Milian Turned Up',
#  'Citizen Rose',
#  'Clean House',
#  'Cold Justice',
#  'Coming Soon to NBC ',
#  'Consumer 101',
#  'Cosplay Melee',
#  'Crimson Force',
#  'Crossbones',
#  'Cucuy: The Boogeyman',
#  'Dahmer on Dahmer: A Serial Killer Speaks',
#  'Daily Pop',
#  'Dallas Divas & Daughters',
#  'Dannemora Prison Break',
#  'Dark Relic',
#  'Dark Web Exposed',
#  'Darklight',
#  'Darkroom',
#  'Dateline',
#  'Dateline: Secrets Uncovered',
#  'Dating: No Filter',
#  'Day of Reckoning',
#  'Days of our Lives',
#  'Dead 7',
#  'Dead In The Water',
#  'Deadline: White House',
#  'Deadly Class',
#  'Deal or No Deal',
#  'Death at the Mansion: Rebecca Zahau',
#  "Denise Richards: It's Complicated",
#  'Dirty John, The Dirty Truth',
#  'Dirty Soap',
#  "Don't Be Tardy",
#  'Dracula',
#  'E! News',
#  'EJ NYC',
#  'Earth Odyssey with Dylan Dreyer',
#  'El Secreto de Selena',
#  'El Secreto de Selena (ENGLISH subs)',
#  "Ellen's Game of Games",
#  'Eric And Jessie',
#  'Escape Club',
#  'Eyewitness',
#  'Face Off',
#  'Face Off: Game Face',
#  'Famously Single',
#  'Filthy Rich: Cattle Drive',
#  'Flip It Like Disick',
#  'Flipping Exes',
#  'Friday Night Lights',
#  'Futurama',
#  'Gary and His Demons',
#  'George to the Rescue',
#  'Ghost In the Shell',
#  'Ghost in the Shell',
#  'Giuliana & Bill',
#  'Global Citizen Festival',
#  'Golden State Killer: Main Suspect',
#  'Good Girls',
#  'Growing Up Chrisley',
#  'Growing Up Fisher',
#  'Guys with Kids',
#  'Happy!',
#  'Hardball with Chris Matthews',
#  'Harry Potter and the Deathly Hallows Part 1',
#  'Harry Potter and the Deathly Hallows, Part 1',
#  'Harry Potter and the Goblet of Fire',
#  'Heroes',
#  'Heroes Reborn',
#  'Hollywood & Football',
#  'Hollywood Game Night',
#  'Hollywood Medium With Tyler Henry',
#  'Hot Listings Miami',
#  'House',
#  'House of the Witch',
#  'How Do I Look?',
#  'How Low Will You Go?',
#  'Husband for Hire',
#  'I Feel Bad',
#  'I Love Jenni (ENGLISH)',
#  'Ice Sharks',
#  'In Ice Cold Blood',
#  'Injustice with Nancy Grace',
#  'Inside the FBI: New York',
#  "Jay Leno's Garage",
#  "Jay Leno's Garage: The Digital Series",
#  'Jeepers Creepers 3',
#  'Jerseylicious',
#  'Jesus Christ Superstar Live in Concert',
#  "Jim Henson's Creature Shop Challenge",
#  'Jodi Arias: In Defense Of',
#  'Journey with Dylan Dreyer',
#  'Just Jillian',
#  'Keeping Up With The Kardashians',
#  'Kemper on Kemper: Inside the Mind of a Serial Killer',
#  'Kidnapped at the Club',
#  'Killer Affair',
#  'Killer Couples',
#  'Killer High',
#  'Killer Motive',
#  'Killing Them Softly',
#  'Killing Versace',
#  'Killjoys',
#  'Kimora: Life in the Fab Lane',
#  'Kings',
#  'Knight Rider',
#  'Knight Rider (1982)',
#  'Knight Rider (1982-1986)',
#  'Knight Rider Classic (1982-1986)',
#  'Kolchak: The Night Stalker',
#  'Krypton',
#  'L.A. Clippers Dance Squad',
#  'La Ley de Zapata',
#  'La Liga Premier',
#  'La Reina del Sur, De Película (English Subtitled)',
#  'Lady Revenge',
#  'Lake Placid: Legacy',
#  'Larrymania',
#  'Last Call with Carson Daly',
#  'Last Chance Kitchen',
#  'Late Night with Seth Meyers',
#  'Law & Order: Los Angeles',
#  'Law & Order: Special Victims Unit',
#  'Law & Order: Trial By Jury',
#  'License to Kill',
#  'Life',
#  'Lipstick Jungle',
#  'Little Big Shots',
#  'MTP Daily',
#  'Mad Money',
#  "Madea's Big Happy Family",
#  "Madea's Witness Protection",
#  'Making It',
#  'Manifest',
#  'Manson: The Women',
#  'Married To Jonas',
#  'Married To Rock',
#  'Married to Medicine',
#  'Married to Medicine Los Angeles',
#  "Marvel's Avengers: Age of Ultron",
#  'Meet the Press',
#  'Megafault',
#  'Megalodon',
#  'Method of a Serial Killer',
#  'Mexican Dynasties',
#  'Miami Vice',
#  'Michael Jackson & Anna Nicole Smith: Bad Medicine',
#  'Midnight, Texas',
#  'Million Dollar Listing Los Angeles',
#  'Million Dollar Listing NY',
#  'Miz & Mrs',
#  'Morning Joe',
#  'Motive',
#  'Mr. Robot',
#  'Mrs. Eastwood & Company',
#  'Murder and Justice: The Case of Martha Moxley',
#  'Murder for Hire',
#  'NBC News Specials',
#  'NBC Nightly News with Lester Holt',
#  'NCIS',
#  'NCIS: Los Angeles',
#  'Naturally, Danny Seo',
#  'Neverknock',
#  'New Amsterdam',
#  'Night Gallery',
#  'Night of the Living Dead',
#  'Nightflyers',
#  'Nightly News Films',
#  'Nightly Pop',
#  'Nightmare Shark',
#  'Not Set',
#  'Noticias Telemundo',
#  'Noticias Telemundo Mediodía',
#  'Open House NYC',
#  'Outsourced',
#  'Paranormal Witness',
#  'Parks and Recreation',
#  'Path of Destruction',
#  'Pearson',
#  'Pegasus vs. Chimera',
#  'Perfect Harmony',
#  'Piranhaconda',
#  'Power Rangers',
#  'Pretty Wild',
#  'Project Runway',
#  'Psych: The Movie',
#  'Punky Brewster',
#  'Quantum Leap',
#  'Queen of the South',
#  'Real Country',
#  'Red: Werewolf Hunter',
#  'Reign of the Gargoyles',
#  'Relatively Nat & Liv',
#  'Return to Downton Abbey: A Grand Event',
#  'Revenge Body With Khloé Kardashian',
#  'Rob & Chyna',
#  'SYFY WIRE: Con After Dark',
#  'Saturday Night Live',
#  'Saved by the Bell',
#  'Saved by the Bell: The New Class',
#  'Secret Lives of the Super Rich',
#  'Seduced by Evil',
#  'Sex and the City',
#  'Shades of Blue',
#  'Shark Tank',
#  'Shrink',
#  'Siren',
#  'Six Million Dollar Man',
#  'Smash',
#  'Snapped',
#  'So Cosmo',
#  'Solace',
#  'Songland',
#  'Southern Charm',
#  'Southern Charm New Orleans',
#  'Squawk on the Street',
#  'State of Affairs',
#  'Stickman',
#  'Straight Up Steve Austin',
#  'Suelta La Sopa',
#  'Suits',
#  'Summer House',
#  'Sunnyside',
#  'Superstore',
#  'Survivorz',
#  'TODAY',
#  'Tacky House',
#  'Team Ninja Warrior',
#  'Temptation Island',
#  'Texicanas',
#  'That Awkward Moment',
#  'The 11th Hour with Brian Williams',
#  'The Bionic Woman',
#  'The Black Donnellys',
#  'The Blacklist',
#  'The Bling Ring',
#  'The Boy (2015)',
#  'The Brave',
#  'The Cape',
#  'The Champion Within',
#  'The Cromarties',
#  'The Disappearance of Susan Cox Powell',
#  'The Enemy Within',
#  'The Equalizer',
#  'The Event',
#  'The Girl with All the Gifts',
#  'The Good Place',
#  'The Hunger Games',
#  'The Hunger Games: Catching Fire',
#  'The Hunger Games: Mockingjay Part 1',
#  'The Hunger Games: Mockingjay Part 2',
#  'The InBetween',
#  'The Incredible Hulk',
#  'The Kelly Clarkson Show',
#  'The Last Witch Hunter',
#  "The Last Word with Lawrence O'Donnell",
#  'The Magicians',
#  'The Office',
#  'The Paley Center Salutes The Good Place',
#  'The Piketon Family Murders',
#  'The Profit',
#  'The Profit: An Inside Look',
#  'The Rachel Maddow Show',
#  'The Radkes',
#  'The Real Housewives of Atlanta',
#  'The Real Housewives of Beverly Hills',
#  'The Real Housewives of Dallas',
#  'The Real Housewives of New Jersey',
#  'The Real Housewives of New York City',
#  'The Real Housewives of Orange County',
#  'The Real Housewives of Potomac',
#  'The Riveras',
#  'The Secret Life of Kids',
#  'The Susan Cox Powell Story',
#  'The Thing',
#  'The Titan Games',
#  'The Tonight Show Starring Jimmy Fallon',
#  'The Turpin 13: Family Secrets Exposed',
#  'The Village',
#  'The Voice',
#  'The Voice Kids',
#  'The Voyager with Josh Garcia',
#  'The Wall',
#  'This Is Us',
#  'This Is Us ',
#  'Tia & Tamera',
#  'Timeless',
#  'Timothy McVeigh: In Defense Of',
#  'Top Chef',
#  'Top Chef Junior',
#  'Total Divas',
#  'Try My Life',
#  'Uncovered: The Cult of Yahweh Ben Yahweh',
#  'Uncovered: The McMartin Family Trials',
#  'Undercover Boss',
#  'Underworld',
#  'Underworld Awakening',
#  'Underworld: Awakening',
#  'Underworld: Evolution',
#  'Underworld: Rise of the Lycans',
#  'Up All Night',
#  'Up and Vanished',
#  'Valerian',
#  'Valerian and the City of a Thousand Planets',
#  'Van Helsing',
#  'Vanderpump Rules',
#  'Very Cavallari',
#  'Vets Saving Pets',
#  'WAGS LA',
#  'WWE NXT',
#  'WWE Raw',
#  'WWE SmackDown',
#  'Watch What Happens Live',
#  'What Would Ryan Lochte Do?',
#  "What's Cooking With Julie Chrisley",
#  'Whitney',
#  'Will & Grace',
#  'Will & Grace (1998)',
#  'Will & Grace: Original',
#  'World of Dance',
#  'XXX: The Return of Xander Cage',
#  'Xena: Warrior Princess',
#  'Young Hercules',
#  'Zombie Tidal Wave',
#  'xXx: The Return of Xander Cage']

# %%
first(reader)
# Out:
# ('2019W29',
#                                                    key     size     week
#  68  clean/year=2019/week=2019W29/ve_20190721_0008....  2515997  2019W29
#  67  clean/year=2019/week=2019W29/ve_20190721_0007....  7455256  2019W29
#  66  clean/year=2019/week=2019W29/ve_20190721_0006....  7378455  2019W29
#  65  clean/year=2019/week=2019W29/ve_20190721_0005....  7353911  2019W29
#  64  clean/year=2019/week=2019W29/ve_20190721_0004....  7334723  2019W29
#  ..                                                ...      ...      ...
#  4   clean/year=2019/week=2019W29/ve_20190715_0004....  7131500  2019W29
#  3   clean/year=2019/week=2019W29/ve_20190715_0003....  7061960  2019W29
#  2   clean/year=2019/week=2019W29/ve_20190715_0002....  7407983  2019W29
#  1   clean/year=2019/week=2019W29/ve_20190715_0001....  7780944  2019W29
#  0   clean/year=2019/week=2019W29/ve_20190715_0000....  7718716  2019W29
#
#  [69 rows x 3 columns])

# %%
work_d = Path(config['WORK_D'])

# %%
list(work_d.glob('*'))
# Out:
# [PosixPath('/Users/wmcabee/DATA/NBC/work/list_clean_files.csv')]

# %%
df['week'] = df['key'].str.extract(r'/week=(\d+W\d\d)')

# %%
df
# Out:
#                                                    key     size     week
# 0    clean/year=2019/week=2019W29/ve_20190715_0000....  7718716  2019W29
# 1    clean/year=2019/week=2019W29/ve_20190715_0001....  7780944  2019W29
# 2    clean/year=2019/week=2019W29/ve_20190715_0002....  7407983  2019W29
# 3    clean/year=2019/week=2019W29/ve_20190715_0003....  7061960  2019W29
# 4    clean/year=2019/week=2019W29/ve_20190715_0004....  7131500  2019W29
# ..                                                 ...      ...      ...
# 809  clean/year=2019/week=2019W40/ve_20191001_0000....  8080038  2019W40
# 810  clean/year=2019/week=2019W40/ve_20191001_0001....  8193853  2019W40
# 811  clean/year=2019/week=2019W40/ve_20191001_0002....  8093150  2019W40
# 812  clean/year=2019/week=2019W40/ve_20191001_0003....  8144759  2019W40
# 813  clean/year=2019/week=2019W40/ve_20191001_0004....  4109810  2019W40
#
# [814 rows x 3 columns]
