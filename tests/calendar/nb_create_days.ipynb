# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from collections import namedtuple
from toolz import first
import numpy as np
from nbc_analysis.utils.debug_utils import runit
from nbc_analysis.utils.config_utils import get_config
from pathlib import Path

from test_create_days import test_create_days
#from nbc_analysis.utils.date_utils import ds_dt2uts_ms, ds_uts_ms2dt, dt2uts_ms, uts_ms2dt

# %%
df = runit(test_create_days)
# Out:
# >> Using default config
# >> creating days calendar,start_day_key=20170101,end_day_key=20210101
# >> wrote file,outfile=/Users/wmcabee/DATA/NBC/calendar/cal_days.parquet,records=1461

# %%
config = get_config(config='default')
calendar_d = Path(config['CALENDAR_D'])
# Out:
# >> Using default config

# %%
infile = first(calendar_d.glob('*'))

df = pd.read_parquet(infile)
df.T
# Out:
#                                  0                    1     \
# day_key                      20170101             20170102
# ordinal                         17167                17168
# day                                 1                    2
# month                               1                    1
# year                             2017                 2017
# dayofweek                           6                    0
# day_name                       Sunday               Monday
# month_name                    January              January
# days_in_month                      31                   31
# quarter                             1                    1
# dayofyear                           1                    2
# week                               52                    1
# weekday                             6                    0
# weekofyear                         52                    1
# week_id                       2017W52              2017W01
# ...
